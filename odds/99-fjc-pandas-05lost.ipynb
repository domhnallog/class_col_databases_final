# %% [markdown]
# # Imports & File Load

# %%
import pandas as pd
import numpy as np
import pandas_profiling
# import requests
# import json
import re
# import os
# import time
# from bs4 import BeautifulSoup
from collections import Counter
# %matplotlib inline

# %%
df = pd.read_csv("sources/judges.csv")
df.head()
# Out:
#        nid   jid Last Name First Name Middle Name Suffix  Birth Month  \
# 0  1394646  3563    Abrams     Leslie       Joyce                 NaN
# 1  1393931  3419    Abrams     Ronnie                             NaN
# 2  1376976     1   Abruzzo    Matthew          T.                 4.0
# 3  1376981     2   Acheson     Marcus      Wilson                 6.0
# 4  1376986     3     Acker    William       Marsh    Jr.         10.0
#
#    Birth Day Birth Year  Birth City  ... Degree (3)  Degree Year (3)  \
# 0        NaN       1974     Madison  ...        NaN              NaN
# 1        NaN       1968    New York  ...        NaN              NaN
# 2       30.0       1889    Brooklyn  ...        NaN              NaN
# 3        7.0       1828  Washington  ...        NaN              NaN
# 4       25.0       1927  Birmingham  ...        NaN              NaN
#
#    School (4)  Degree (4) Degree Year (4) School (5) Degree (5)  \
# 0         NaN         NaN             NaN        NaN        NaN
# 1         NaN         NaN             NaN        NaN        NaN
# 2         NaN         NaN             NaN        NaN        NaN
# 3         NaN         NaN             NaN        NaN        NaN
# 4         NaN         NaN             NaN        NaN        NaN
#
#   Degree Year (5)                                Professional Career  \
# 0             NaN  Law clerk, Hon. Marvin J. Garbis, U.S. Distric...
# 1             NaN  Law clerk, Hon. Thomas P. Griesa, U.S. Distric...
# 2             NaN    Private practice, Brooklyn, New York, 1910-1936
# 3             NaN  Private practice, Pittsburgh, Pennsylvania, 18...
# 4             NaN  U.S. Army private first class, 1946-1947; Priv...
#
#   Other Nominations/Recess Appointments
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
# [5 rows x 201 columns]

# %% [markdown]
# # File Investigation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3694 entries, 0 to 3693
# Columns: 201 entries, nid to Other Nominations/Recess Appointments
# dtypes: float64(43), int64(2), object(156)
# memory usage: 3.5+ MB

# %%
original_size = df.memory_usage().sum()
original_size
# Out:
# 3634936

# %%
# df.dtypes
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3694 entries, 0 to 3693
# Data columns (total 201 columns):
# nid                                      int64
# jid                                      int64
# Last Name                                object
# First Name                               object
# Middle Name                              object
# Suffix                                   object
# Birth Month                              float64
# Birth Day                                float64
# Birth Year                               object
# Birth City                               object
# Birth State                              object
# Death Month                              float64
# Death Day                                float64
# Death Year                               float64
# Death City                               object
# Death State                              object
# Gender                                   object
# Race or Ethnicity                        object
# Court Type (1)                           object
# Court Name (1)                           object
# Appointment Title (1)                    object
# Appointing President (1)                 object
# Party of Appointing President (1)        object
# Reappointing President (1)               object
# Party of Reappointing President (1)      object
# ABA Rating (1)                           object
# Seat ID (1)                              object
# Statute Authorizing New Seat (1)         object
# Recess Appointment Date (1)              object
# Nomination Date (1)                      object
# Committee Referral Date (1)              object
# Hearing Date (1)                         object
# Judiciary Committee Action (1)           object
# Committee Action Date (1)                object
# Senate Vote Type (1)                     object
# Ayes/Nays (1)                            object
# Confirmation Date (1)                    object
# Commission Date (1)                      object
# Service as Chief Judge, Begin (1)        float64
# Service as Chief Judge, End (1)          float64
# 2nd Service as Chief Judge, Begin (1)    float64
# 2nd Service as Chief Judge, End (1)      float64
# Senior Status Date (1)                   object
# Termination (1)                          object
# Termination Date (1)                     object
# Court Type (2)                           object
# Court Name (2)                           object
# Appointment Title (2)                    object
# Appointing President (2)                 object
# Party of Appointing President (2)        object
# Reappointing President (2)               float64
# Party of Reappointing President (2)      float64
# ABA Rating (2)                           object
# Seat ID (2)                              object
# Statute Authorizing New Seat (2)         object
# Recess Appointment Date (2)              object
# Nomination Date (2)                      object
# Committee Referral Date (2)              object
# Hearing Date (2)                         object
# Judiciary Committee Action (2)           object
# Committee Action Date (2)                object
# Senate Vote Type (2)                     object
# Ayes/Nays (2)                            object
# Confirmation Date (2)                    object
# Commission Date (2)                      object
# Service as Chief Judge, Begin (2)        float64
# Service as Chief Judge, End (2)          float64
# 2nd Service as Chief Judge, Begin (2)    float64
# 2nd Service as Chief Judge, End (2)      float64
# Senior Status Date (2)                   object
# Termination (2)                          object
# Termination Date (2)                     object
# Court Type (3)                           object
# Court Name (3)                           object
# Appointment Title (3)                    object
# Appointing President (3)                 object
# Party of Appointing President (3)        object
# Reappointing President (3)               float64
# Party of Reappointing President (3)      float64
# ABA Rating (3)                           object
# Seat ID (3)                              object
# Statute Authorizing New Seat (3)         object
# Recess Appointment Date (3)              object
# Nomination Date (3)                      object
# Committee Referral Date (3)              object
# Hearing Date (3)                         object
# Judiciary Committee Action (3)           object
# Committee Action Date (3)                object
# Senate Vote Type (3)                     object
# Ayes/Nays (3)                            object
# Confirmation Date (3)                    object
# Commission Date (3)                      object
# Service as Chief Judge, Begin (3)        float64
# Service as Chief Judge, End (3)          float64
# 2nd Service as Chief Judge, Begin (3)    float64
# 2nd Service as Chief Judge, End (3)      float64
# Senior Status Date (3)                   object
# Termination (3)                          object
# Termination Date (3)                     object
# Court Type (4)                           object
# Court Name (4)                           object
# Appointment Title (4)                    object
# Appointing President (4)                 object
# Party of Appointing President (4)        object
# Reappointing President (4)               float64
# Party of Reappointing President (4)      float64
# ABA Rating (4)                           object
# Seat ID (4)                              object
# Statute Authorizing New Seat (4)         object
# Recess Appointment Date (4)              object
# Nomination Date (4)                      object
# Committee Referral Date (4)              object
# Hearing Date (4)                         object
# Judiciary Committee Action (4)           object
# Committee Action Date (4)                object
# Senate Vote Type (4)                     object
# Ayes/Nays (4)                            object
# Confirmation Date (4)                    object
# Commission Date (4)                      object
# Service as Chief Judge, Begin (4)        float64
# Service as Chief Judge, End (4)          float64
# 2nd Service as Chief Judge, Begin (4)    float64
# 2nd Service as Chief Judge, End (4)      float64
# Senior Status Date (4)                   object
# Termination (4)                          object
# Termination Date (4)                     object
# Court Type (5)                           object
# Court Name (5)                           object
# Appointment Title (5)                    object
# Appointing President (5)                 object
# Party of Appointing President (5)        object
# Reappointing President (5)               float64
# Party of Reappointing President (5)      float64
# ABA Rating (5)                           float64
# Seat ID (5)                              object
# Statute Authorizing New Seat (5)         object
# Recess Appointment Date (5)              object
# Nomination Date (5)                      object
# Committee Referral Date (5)              object
# Hearing Date (5)                         object
# Judiciary Committee Action (5)           object
# Committee Action Date (5)                object
# Senate Vote Type (5)                     object
# Ayes/Nays (5)                            object
# Confirmation Date (5)                    object
# Commission Date (5)                      object
# Service as Chief Judge, Begin (5)        float64
# Service as Chief Judge, End (5)          float64
# 2nd Service as Chief Judge, Begin (5)    float64
# 2nd Service as Chief Judge, End (5)      float64
# Senior Status Date (5)                   object
# Termination (5)                          object
# Termination Date (5)                     object
# Court Type (6)                           object
# Court Name (6)                           object
# Appointment Title (6)                    object
# Appointing President (6)                 object
# Party of Appointing President (6)        object
# Reappointing President (6)               float64
# Party of Reappointing President (6)      float64
# ABA Rating (6)                           float64
# Seat ID (6)                              object
# Statute Authorizing New Seat (6)         object
# Recess Appointment Date (6)              object
# Nomination Date (6)                      object
# Committee Referral Date (6)              object
# Hearing Date (6)                         object
# Judiciary Committee Action (6)           object
# Committee Action Date (6)                object
# Senate Vote Type (6)                     object
# Ayes/Nays (6)                            object
# Confirmation Date (6)                    object
# Commission Date (6)                      object
# Service as Chief Judge, Begin (6)        float64
# Service as Chief Judge, End (6)          float64
# 2nd Service as Chief Judge, Begin (6)    float64
# 2nd Service as Chief Judge, End (6)      float64
# Senior Status Date (6)                   object
# Termination (6)                          object
# Termination Date (6)                     object
# Other Federal Judicial Service (1)       object
# Other Federal Judicial Service (2)       object
# Other Federal Judicial Service (3)       object
# Other Federal Judicial Service (4)       object
# School (1)                               object
# Degree (1)                               object
# Degree Year (1)                          object
# School (2)                               object
# Degree (2)                               object
# Degree Year (2)                          object
# School (3)                               object
# Degree (3)                               object
# Degree Year (3)                          object
# School (4)                               object
# Degree (4)                               object
# Degree Year (4)                          float64
# School (5)                               object
# Degree (5)                               object
# Degree Year (5)                          float64
# Professional Career                      object
# Other Nominations/Recess Appointments    object
# dtypes: float64(43), int64(2), object(156)
# memory usage: 3.5+ MB

# %%
# df = df.drop(columns='url')

# %%
# df.profile_report()

# %% [markdown]
# # Basic Clean
# - make easy column headers
# - remove the circa abbreviation everywhere
# - convert separated birth/death info to united field
# - convert all string dates into datetime
# - convert year-only dates into datetime

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace('/', '-')
df.columns = df.columns.str.replace('\(|\)|,', '')
df.replace('ca. ','',regex=True,inplace=True)

# %%
df['Birth_Month'] = pd.to_numeric(df['Birth_Month'], errors='coerce').fillna(value=9).astype(int)
df['Birth_Day'] = pd.to_numeric(df['Birth_Day'], errors='coerce').fillna(value=30).astype(int)
df['Birth_Year'] = pd.to_numeric(df['Birth_Year'], errors='coerce').fillna(value=1677).astype(int)
df['Birth_Date'] = df.Birth_Year.map(str).astype(str).str.zfill(4) + '-' + df.Birth_Month.map(str).astype(str).str.zfill(2) + '-' + df.Birth_Day.map(str).astype(str).str.zfill(2)
df['Death_Month'] = pd.to_numeric(df['Death_Month'], errors='coerce').fillna(value=9).astype(int)
df['Death_Day'] = pd.to_numeric(df['Death_Day'], errors='coerce').fillna(value=30).astype(int)
df['Death_Year'] = pd.to_numeric(df['Death_Year'], errors='coerce').fillna(value=1677).astype(int)
df['Death_Date'] = df.Death_Year.map(str).astype(str).str.zfill(4) + '-' + df.Death_Month.map(str).astype(str).str.zfill(2) + '-' + df.Death_Day.map(str).astype(str).str.zfill(2)

# %%
df.Death_Date.head()
# Out:
# 0    1677-09-30
# 1    1677-09-30
# 2    1971-05-28
# 3    1906-06-21
# 4    2018-06-21
# Name: Death_Date, dtype: object

# %%
forceDT = [
    'Birth_Date',
    'Death_Date',
    'Recess_Appointment_Date_1',
    'Nomination_Date_1',
    'Committee_Referral_Date_1',
    'Hearing_Date_1',
    'Committee_Action_Date_1',
    'Confirmation_Date_1',
    'Commission_Date_1',
    'Service_as_Chief_Judge_Begin_1',
    'Service_as_Chief_Judge_End_1',
    '2nd_Service_as_Chief_Judge_Begin_1',
    '2nd_Service_as_Chief_Judge_End_1',
    'Senior_Status_Date_1',
    'Termination_Date_1',
    'Recess_Appointment_Date_2',
    'Nomination_Date_2',
    'Committee_Referral_Date_2',
    'Hearing_Date_2',
    'Committee_Action_Date_2',
    'Confirmation_Date_2',
    'Commission_Date_2',
    'Service_as_Chief_Judge_Begin_2',
    'Service_as_Chief_Judge_End_2',
    '2nd_Service_as_Chief_Judge_Begin_2',
    '2nd_Service_as_Chief_Judge_End_2',
    'Senior_Status_Date_2',
    'Termination_Date_2',
    'Recess_Appointment_Date_3',
    'Nomination_Date_3',
    'Committee_Referral_Date_3',
    'Hearing_Date_3',
    'Committee_Action_Date_3',
    'Confirmation_Date_3',
    'Commission_Date_3',
    'Service_as_Chief_Judge_Begin_3',
    'Service_as_Chief_Judge_End_3',
    '2nd_Service_as_Chief_Judge_Begin_3',
    '2nd_Service_as_Chief_Judge_End_3',
    'Senior_Status_Date_3',
    'Termination_Date_3',
    'Recess_Appointment_Date_4',
    'Nomination_Date_4',
    'Committee_Referral_Date_4',
    'Hearing_Date_4',
    'Committee_Action_Date_4',
    'Confirmation_Date_4',
    'Commission_Date_4',
    'Service_as_Chief_Judge_Begin_4',
    'Service_as_Chief_Judge_End_4',
    '2nd_Service_as_Chief_Judge_Begin_4',
    '2nd_Service_as_Chief_Judge_End_4',
    'Senior_Status_Date_4',
    'Termination_Date_4',
    'Recess_Appointment_Date_5',
    'Nomination_Date_5',
    'Committee_Referral_Date_5',
    'Hearing_Date_5',
    'Committee_Action_Date_5',
    'Confirmation_Date_5',
    'Commission_Date_5',
    'Service_as_Chief_Judge_Begin_5',
    'Service_as_Chief_Judge_End_5',
    '2nd_Service_as_Chief_Judge_Begin_5',
    '2nd_Service_as_Chief_Judge_End_5',
    'Senior_Status_Date_5',
    'Termination_Date_5',
    'Recess_Appointment_Date_6',
    'Nomination_Date_6',
    'Committee_Referral_Date_6',
    'Hearing_Date_6',
    'Committee_Action_Date_6',
    'Confirmation_Date_6',
    'Commission_Date_6',
    'Service_as_Chief_Judge_Begin_6',
    'Service_as_Chief_Judge_End_6',
    '2nd_Service_as_Chief_Judge_Begin_6',
    '2nd_Service_as_Chief_Judge_End_6',
    'Senior_Status_Date_6',
    'Termination_Date_6'
]
df[forceDT] = df[forceDT].apply(pd.to_datetime)
df.dtypes.head(50)
# Out:
# nid                                            int64
# jid                                            int64
# Last_Name                                     object
# First_Name                                    object
# Middle_Name                                   object
# Suffix                                        object
# Birth_Month                                    int32
# Birth_Day                                      int32
# Birth_Year                                     int32
# Birth_City                                    object
# Birth_State                                   object
# Death_Month                                    int32
# Death_Day                                      int32
# Death_Year                                     int32
# Death_City                                    object
# Death_State                                   object
# Gender                                        object
# Race_or_Ethnicity                             object
# Court_Type_1                                  object
# Court_Name_1                                  object
# Appointment_Title_1                           object
# Appointing_President_1                        object
# Party_of_Appointing_President_1               object
# Reappointing_President_1                      object
# Party_of_Reappointing_President_1             object
# ABA_Rating_1                                  object
# Seat_ID_1                                     object
# Statute_Authorizing_New_Seat_1                object
# Recess_Appointment_Date_1             datetime64[ns]
# Nomination_Date_1                     datetime64[ns]
# Committee_Referral_Date_1             datetime64[ns]
# Hearing_Date_1                        datetime64[ns]
# Judiciary_Committee_Action_1                  object
# Committee_Action_Date_1               datetime64[ns]
# Senate_Vote_Type_1                            object
# Ayes-Nays_1                                   object
# Confirmation_Date_1                   datetime64[ns]
# Commission_Date_1                     datetime64[ns]
# Service_as_Chief_Judge_Begin_1        datetime64[ns]
# Service_as_Chief_Judge_End_1          datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_1    datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_1      datetime64[ns]
# Senior_Status_Date_1                  datetime64[ns]
# Termination_1                                 object
# Termination_Date_1                    datetime64[ns]
# Court_Type_2                                  object
# Court_Name_2                                  object
# Appointment_Title_2                           object
# Appointing_President_2                        object
# Party_of_Appointing_President_2               object
# dtype: object

# %%
df['Degree_Year_1'] = pd.to_datetime(df['Degree_Year_1'],format='%Y', errors='coerce')
df['Degree_Year_2'] = pd.to_datetime(df['Degree_Year_2'],format='%Y', errors='coerce')
df['Degree_Year_3'] = pd.to_datetime(df['Degree_Year_3'],format='%Y', errors='coerce')
df['Degree_Year_4'] = pd.to_datetime(df['Degree_Year_4'],format='%Y', errors='coerce')
df['Degree_Year_5'] = pd.to_datetime(df['Degree_Year_5'],format='%Y', errors='coerce')

# %%
df['Full_Name'] = df.First_Name + ' ' + df.Middle_Name + ' ' + df.Last_Name
df.Full_Name.replace(r'\s{2,4}',' ',regex=True,inplace=True)
df.Full_Name.head()
# Out:
# 0      Leslie Joyce Abrams
# 1            Ronnie Abrams
# 2       Matthew T. Abruzzo
# 3    Marcus Wilson Acheson
# 4      William Marsh Acker
# Name: Full_Name, dtype: object

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3694 entries, 0 to 3693
# Data columns (total 204 columns):
# nid                                      int64
# jid                                      int64
# Last_Name                                object
# First_Name                               object
# Middle_Name                              object
# Suffix                                   object
# Birth_Month                              int32
# Birth_Day                                int32
# Birth_Year                               int32
# Birth_City                               object
# Birth_State                              object
# Death_Month                              int32
# Death_Day                                int32
# Death_Year                               int32
# Death_City                               object
# Death_State                              object
# Gender                                   object
# Race_or_Ethnicity                        object
# Court_Type_1                             object
# Court_Name_1                             object
# Appointment_Title_1                      object
# Appointing_President_1                   object
# Party_of_Appointing_President_1          object
# Reappointing_President_1                 object
# Party_of_Reappointing_President_1        object
# ABA_Rating_1                             object
# Seat_ID_1                                object
# Statute_Authorizing_New_Seat_1           object
# Recess_Appointment_Date_1                datetime64[ns]
# Nomination_Date_1                        datetime64[ns]
# Committee_Referral_Date_1                datetime64[ns]
# Hearing_Date_1                           datetime64[ns]
# Judiciary_Committee_Action_1             object
# Committee_Action_Date_1                  datetime64[ns]
# Senate_Vote_Type_1                       object
# Ayes-Nays_1                              object
# Confirmation_Date_1                      datetime64[ns]
# Commission_Date_1                        datetime64[ns]
# Service_as_Chief_Judge_Begin_1           datetime64[ns]
# Service_as_Chief_Judge_End_1             datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_1       datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_1         datetime64[ns]
# Senior_Status_Date_1                     datetime64[ns]
# Termination_1                            object
# Termination_Date_1                       datetime64[ns]
# Court_Type_2                             object
# Court_Name_2                             object
# Appointment_Title_2                      object
# Appointing_President_2                   object
# Party_of_Appointing_President_2          object
# Reappointing_President_2                 float64
# Party_of_Reappointing_President_2        float64
# ABA_Rating_2                             object
# Seat_ID_2                                object
# Statute_Authorizing_New_Seat_2           object
# Recess_Appointment_Date_2                datetime64[ns]
# Nomination_Date_2                        datetime64[ns]
# Committee_Referral_Date_2                datetime64[ns]
# Hearing_Date_2                           datetime64[ns]
# Judiciary_Committee_Action_2             object
# Committee_Action_Date_2                  datetime64[ns]
# Senate_Vote_Type_2                       object
# Ayes-Nays_2                              object
# Confirmation_Date_2                      datetime64[ns]
# Commission_Date_2                        datetime64[ns]
# Service_as_Chief_Judge_Begin_2           datetime64[ns]
# Service_as_Chief_Judge_End_2             datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_2       datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_2         datetime64[ns]
# Senior_Status_Date_2                     datetime64[ns]
# Termination_2                            object
# Termination_Date_2                       datetime64[ns]
# Court_Type_3                             object
# Court_Name_3                             object
# Appointment_Title_3                      object
# Appointing_President_3                   object
# Party_of_Appointing_President_3          object
# Reappointing_President_3                 float64
# Party_of_Reappointing_President_3        float64
# ABA_Rating_3                             object
# Seat_ID_3                                object
# Statute_Authorizing_New_Seat_3           object
# Recess_Appointment_Date_3                datetime64[ns]
# Nomination_Date_3                        datetime64[ns]
# Committee_Referral_Date_3                datetime64[ns]
# Hearing_Date_3                           datetime64[ns]
# Judiciary_Committee_Action_3             object
# Committee_Action_Date_3                  datetime64[ns]
# Senate_Vote_Type_3                       object
# Ayes-Nays_3                              object
# Confirmation_Date_3                      datetime64[ns]
# Commission_Date_3                        datetime64[ns]
# Service_as_Chief_Judge_Begin_3           datetime64[ns]
# Service_as_Chief_Judge_End_3             datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_3       datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_3         datetime64[ns]
# Senior_Status_Date_3                     datetime64[ns]
# Termination_3                            object
# Termination_Date_3                       datetime64[ns]
# Court_Type_4                             object
# Court_Name_4                             object
# Appointment_Title_4                      object
# Appointing_President_4                   object
# Party_of_Appointing_President_4          object
# Reappointing_President_4                 float64
# Party_of_Reappointing_President_4        float64
# ABA_Rating_4                             object
# Seat_ID_4                                object
# Statute_Authorizing_New_Seat_4           object
# Recess_Appointment_Date_4                datetime64[ns]
# Nomination_Date_4                        datetime64[ns]
# Committee_Referral_Date_4                datetime64[ns]
# Hearing_Date_4                           datetime64[ns]
# Judiciary_Committee_Action_4             object
# Committee_Action_Date_4                  datetime64[ns]
# Senate_Vote_Type_4                       object
# Ayes-Nays_4                              object
# Confirmation_Date_4                      datetime64[ns]
# Commission_Date_4                        datetime64[ns]
# Service_as_Chief_Judge_Begin_4           datetime64[ns]
# Service_as_Chief_Judge_End_4             datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_4       datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_4         datetime64[ns]
# Senior_Status_Date_4                     datetime64[ns]
# Termination_4                            object
# Termination_Date_4                       datetime64[ns]
# Court_Type_5                             object
# Court_Name_5                             object
# Appointment_Title_5                      object
# Appointing_President_5                   object
# Party_of_Appointing_President_5          object
# Reappointing_President_5                 float64
# Party_of_Reappointing_President_5        float64
# ABA_Rating_5                             float64
# Seat_ID_5                                object
# Statute_Authorizing_New_Seat_5           object
# Recess_Appointment_Date_5                datetime64[ns]
# Nomination_Date_5                        datetime64[ns]
# Committee_Referral_Date_5                datetime64[ns]
# Hearing_Date_5                           datetime64[ns]
# Judiciary_Committee_Action_5             object
# Committee_Action_Date_5                  datetime64[ns]
# Senate_Vote_Type_5                       object
# Ayes-Nays_5                              object
# Confirmation_Date_5                      datetime64[ns]
# Commission_Date_5                        datetime64[ns]
# Service_as_Chief_Judge_Begin_5           datetime64[ns]
# Service_as_Chief_Judge_End_5             datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_5       datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_5         datetime64[ns]
# Senior_Status_Date_5                     datetime64[ns]
# Termination_5                            object
# Termination_Date_5                       datetime64[ns]
# Court_Type_6                             object
# Court_Name_6                             object
# Appointment_Title_6                      object
# Appointing_President_6                   object
# Party_of_Appointing_President_6          object
# Reappointing_President_6                 float64
# Party_of_Reappointing_President_6        float64
# ABA_Rating_6                             float64
# Seat_ID_6                                object
# Statute_Authorizing_New_Seat_6           object
# Recess_Appointment_Date_6                datetime64[ns]
# Nomination_Date_6                        datetime64[ns]
# Committee_Referral_Date_6                datetime64[ns]
# Hearing_Date_6                           datetime64[ns]
# Judiciary_Committee_Action_6             object
# Committee_Action_Date_6                  datetime64[ns]
# Senate_Vote_Type_6                       object
# Ayes-Nays_6                              object
# Confirmation_Date_6                      datetime64[ns]
# Commission_Date_6                        datetime64[ns]
# Service_as_Chief_Judge_Begin_6           datetime64[ns]
# Service_as_Chief_Judge_End_6             datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_6       datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_6         datetime64[ns]
# Senior_Status_Date_6                     datetime64[ns]
# Termination_6                            object
# Termination_Date_6                       datetime64[ns]
# Other_Federal_Judicial_Service_1         object
# Other_Federal_Judicial_Service_2         object
# Other_Federal_Judicial_Service_3         object
# Other_Federal_Judicial_Service_4         object
# School_1                                 object
# Degree_1                                 object
# Degree_Year_1                            datetime64[ns]
# School_2                                 object
# Degree_2                                 object
# Degree_Year_2                            datetime64[ns]
# School_3                                 object
# Degree_3                                 object
# Degree_Year_3                            datetime64[ns]
# School_4                                 object
# Degree_4                                 object
# Degree_Year_4                            datetime64[ns]
# School_5                                 object
# Degree_5                                 object
# Degree_Year_5                            datetime64[ns]
# Professional_Career                      object
# Other_Nominations-Recess_Appointments    object
# Birth_Date                               datetime64[ns]
# Death_Date                               datetime64[ns]
# Full_Name                                object
# dtypes: datetime64[ns](85), float64(12), int32(6), int64(2), object(99)
# memory usage: 4.3+ MB

# %% [markdown]
# # Basic Research

# %% [markdown]
# ### Most Appointments

# %%
df.Appointing_President_1.value_counts().head()
# Out:
# William J. Clinton    357
# Ronald Reagan         347
# George W. Bush        310
# Barack Obama          308
# Jimmy Carter          247
# Name: Appointing_President_1, dtype: int64

# %% [markdown]
# ### Qualifications
# - ABA Rating
# - Committee Recommendations
# - Termination Types

# %%
df.ABA_Rating_1.value_counts()
# Out:
# Well Qualified                    1248
# Qualified                          948
# Not Qualified                       17
# Exceptionally Well Qualified        11
# Not Qualified By Reason of Age       3
# Name: ABA_Rating_1, dtype: int64

# %%
df[df.ABA_Rating_1.str.contains("Not", na=False)]['Appointing_President_1'].value_counts()
# Out:
# Lyndon B. Johnson     5
# George W. Bush        4
# Donald J. Trump       4
# William J. Clinton    3
# Jimmy Carter          3
# John F. Kennedy       1
# Name: Appointing_President_1, dtype: int64

# %%
df[df.ABA_Rating_1.str.contains("Not", na=False)][['Last_Name','ABA_Rating_1','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#           Last_Name                    ABA_Rating_1 Appointing_President_1  \
# 1829          Kobes                   Not Qualified        Donald J. Trump
# 1242        Goodwin                   Not Qualified        Donald J. Trump
# 3261         Teeter                   Not Qualified        Donald J. Trump
# 1269          Grasz                   Not Qualified        Donald J. Trump
# 3385  Van Tatenhove                   Not Qualified         George W. Bush
# 1609       Irizarry                   Not Qualified         George W. Bush
# 220         Benitez                   Not Qualified         George W. Bush
# 444         Bunning                   Not Qualified         George W. Bush
# 1352       Hamilton                   Not Qualified     William J. Clinton
# 1724           Katz                   Not Qualified     William J. Clinton
# 3565       Williams                   Not Qualified     William J. Clinton
# 637          Clemon                   Not Qualified           Jimmy Carter
# 1791           Kidd  Not Qualified By Reason of Age           Jimmy Carter
# 2487        O'Brien                   Not Qualified           Jimmy Carter
# 2166        McEntee                   Not Qualified      Lyndon B. Johnson
# 2378         Muecke                   Not Qualified      Lyndon B. Johnson
# 1247         Gordon                   Not Qualified      Lyndon B. Johnson
# 605        Christie  Not Qualified By Reason of Age      Lyndon B. Johnson
# 1565         Hughes  Not Qualified By Reason of Age        John F. Kennedy
# 2703     Rabinovitz                   Not Qualified      Lyndon B. Johnson
#
#      Confirmation_Date_1
# 1829          2018-12-11
# 1242          2018-08-28
# 3261          2018-08-01
# 1269          2017-12-12
# 3385          2005-12-21
# 1609          2004-06-24
# 220           2004-06-17
# 444           2002-02-14
# 1352          1994-10-07
# 1724          1994-10-07
# 3565          1994-08-17
# 637           1980-06-26
# 1791          1979-12-20
# 2487          1978-10-04
# 2166          1965-08-31
# 2378          1964-09-29
# 1247          1964-05-27
# 605           1964-04-30
# 1565          1962-03-16
# 2703                 NaT

# %%
df[df.ABA_Rating_2.str.contains("Not", na=False)][['Last_Name','ABA_Rating_2','Appointing_President_2','Confirmation_Date_2']].sort_values(by='Confirmation_Date_2', ascending=False)
# Out:
#      Last_Name                    ABA_Rating_2 Appointing_President_2  \
# 2487   O'Brien                   Not Qualified           Jimmy Carter
# 605   Christie  Not Qualified By Reason of Age      Lyndon B. Johnson
#
#      Confirmation_Date_2
# 2487          1978-10-04
# 605           1964-04-30

# %%
df[df.ABA_Rating_3.str.contains("Not", na=False)][['Last_Name','ABA_Rating_3','Appointing_President_3','Confirmation_Date_3']].sort_values(by='Confirmation_Date_3', ascending=False)
# Out:
# Empty DataFrame
# Columns: [Last_Name, ABA_Rating_3, Appointing_President_3, Confirmation_Date_3]
# Index: []

# %%
df.Judiciary_Committee_Action_1.value_counts()
# Out:
# Reported (favorably)                     3378
# Reported (no recommendation recorded)      99
# Not Referred to Committee                  84
# No Committee before December 10, 1816      84
# Not Reported                               15
# Reported (unfavorably)                      9
# Reported (unknown)                          9
# Reported (without recommendation)           4
# Recommended Postponement                    1
# Name: Judiciary_Committee_Action_1, dtype: int64

# %%
df[~df.Judiciary_Committee_Action_1.str.contains("\(favorably", na=False)][['Last_Name','Judiciary_Committee_Action_1','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False).dropna().head(60)
# Out:
#           Last_Name           Judiciary_Committee_Action_1  \
# 1512         Holmes      Reported (without recommendation)
# 2055         Manion      Reported (without recommendation)
# 2286         Miller              Not Referred to Committee
# 1456         Hickey  Reported (no recommendation recorded)
# 2969          Seitz  Reported (no recommendation recorded)
# 3091          Smith  Reported (no recommendation recorded)
# 1430          Heebe  Reported (no recommendation recorded)
# 975         Edwards  Reported (no recommendation recorded)
# 935        Dumbauld                           Not Reported
# 3588         Wilson  Reported (no recommendation recorded)
# 3171     Stephenson  Reported (no recommendation recorded)
# 298            Bone              Not Referred to Committee
# 1568          Hulen              Not Referred to Committee
# 937          Duncan              Not Referred to Committee
# 663            Cole              Not Referred to Committee
# 479          Byrnes              Not Referred to Committee
# 2289         Miller              Not Referred to Committee
# 2949  Schwellenbach              Not Referred to Committee
# 1674          Jones                           Not Reported
# 2392       Murphree  Reported (no recommendation recorded)
# 972        Edgerton  Reported (no recommendation recorded)
# 3405         Vinson  Reported (no recommendation recorded)
# 1621        Jackson  Reported (no recommendation recorded)
# 349         Bratton              Not Referred to Committee
# 2707          Ragon              Not Referred to Committee
# 2211       McMillan  Reported (no recommendation recorded)
# 3214     Sutherland              Not Referred to Committee
# 1778         Kenyon              Not Referred to Committee
# 2601         Peters                     Reported (unknown)
# 2353         Morris                     Reported (unknown)
# 1771        Kennedy                     Reported (unknown)
# 2142      McClintic                     Reported (unknown)
# 1490       Hoehling                     Reported (unknown)
# 1300         Groner                     Reported (unknown)
# 2854           Ross                     Reported (unknown)
# 119           Baker                     Reported (unknown)
# 2019           Luse                     Reported (unknown)
# 423           Bryan                           Not Reported
# 1648        Johnson              Not Referred to Committee
# 634         Clayton              Not Referred to Committee
# 1685          Jones                           Not Reported
# 3531          White              Not Referred to Committee
# 3025         Shiras      Reported (without recommendation)
# 1136         Fuller      Reported (without recommendation)
# 1867          Lamar                 Reported (unfavorably)
# 1618        Jackson              Not Referred to Committee
# 2114       Matthews                 Reported (unfavorably)
# 1629          James                           Not Reported
# 2360         Morris              Not Referred to Committee
# 1646        Johnson              Not Referred to Committee
# 952            Dyer              Not Referred to Committee
# 3228          Swing              Not Referred to Committee
# 3191          Story              Not Referred to Committee
# 912           Drake              Not Referred to Committee
# 620           Clark              Not Referred to Committee
# 2007         Lowell              Not Referred to Committee
# 2478           Nott              Not Referred to Committee
# 580           Chase              Not Referred to Committee
# 842         Delahay  Reported (no recommendation recorded)
# 945          Durell  Reported (no recommendation recorded)
#
#      Appointing_President_1 Confirmation_Date_1
# 1512         George W. Bush          2004-07-06
# 2055          Ronald Reagan          1986-06-26
# 2286       Richard M. Nixon          1973-06-28
# 1456      Lyndon B. Johnson          1966-06-09
# 2969      Lyndon B. Johnson          1966-06-09
# 3091      Lyndon B. Johnson          1966-03-25
# 1430      Lyndon B. Johnson          1966-03-25
# 975         John F. Kennedy          1963-12-16
# 935         John F. Kennedy          1961-08-02
# 3588        John F. Kennedy          1961-06-14
# 3171   Dwight D. Eisenhower          1960-05-26
# 298   Franklin D. Roosevelt          1944-04-01
# 1568  Franklin D. Roosevelt          1943-07-08
# 937   Franklin D. Roosevelt          1943-07-08
# 663   Franklin D. Roosevelt          1942-05-11
# 479   Franklin D. Roosevelt          1941-06-12
# 2289  Franklin D. Roosevelt          1941-01-31
# 2949  Franklin D. Roosevelt          1940-05-06
# 1674  Franklin D. Roosevelt          1940-04-10
# 2392  Franklin D. Roosevelt          1938-05-17
# 972   Franklin D. Roosevelt          1937-12-09
# 3405  Franklin D. Roosevelt          1937-12-09
# 1621  Franklin D. Roosevelt          1937-12-09
# 349   Franklin D. Roosevelt          1933-06-01
# 2707  Franklin D. Roosevelt          1933-05-12
# 2211         Herbert Hoover          1932-01-12
# 3214      Warren G. Harding          1922-09-05
# 1778      Warren G. Harding          1922-01-31
# 2601      Warren G. Harding          1921-11-14
# 2353      Warren G. Harding          1921-10-25
# 1771      Warren G. Harding          1921-10-25
# 2142      Warren G. Harding          1921-07-25
# 1490      Warren G. Harding          1921-06-13
# 1300      Warren G. Harding          1921-06-02
# 2854      Warren G. Harding          1921-05-31
# 119       Warren G. Harding          1921-05-03
# 2019      Warren G. Harding          1921-04-27
# 423          Woodrow Wilson          1920-04-23
# 1648         Woodrow Wilson          1917-10-01
# 634          Woodrow Wilson          1914-05-02
# 1685     Theodore Roosevelt          1901-12-17
# 3531       Grover Cleveland          1894-02-19
# 3025      Benjamin Harrison          1892-07-26
# 1136       Grover Cleveland          1888-07-20
# 1867       Grover Cleveland          1888-01-16
# 1618       Grover Cleveland          1886-04-12
# 2114      James A. Garfield          1881-05-12
# 1629    Rutherford B. Hayes          1879-12-10
# 2360    Rutherford B. Hayes          1879-07-01
# 1646          Ulysses Grant          1875-12-15
# 952           Ulysses Grant          1875-02-10
# 3228          Ulysses Grant          1871-03-30
# 3191          Ulysses Grant          1871-03-03
# 912           Ulysses Grant          1870-12-12
# 620          Andrew Johnson          1866-07-27
# 2007        Abraham Lincoln          1865-03-11
# 2478        Abraham Lincoln          1865-02-22
# 580         Abraham Lincoln          1864-12-06
# 842         Abraham Lincoln          1864-03-15
# 945         Abraham Lincoln          1864-02-17

# %%
df.Termination_1.value_counts()
# Out:
# Death                                       1417
# Appointment to Another Judicial Position     353
# Retirement                                   271
# Resignation                                  235
# Reassignment                                 116
# Abolition of Court                            29
# Recess Appointment-Not Confirmed              23
# Impeachment & Conviction                       7
# Name: Termination_1, dtype: int64

# %%
df[df.Termination_1.str.contains("Impeachment", na=False)][['First_Name','Last_Name','Termination_1','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#      First_Name  Last_Name             Termination_1 Appointing_President_1  \
# 2656         G.   Porteous  Impeachment & Conviction     William J. Clinton
# 1400      Alcee   Hastings  Impeachment & Conviction           Jimmy Carter
# 612       Harry  Claiborne  Impeachment & Conviction           Jimmy Carter
# 2462     Walter      Nixon  Impeachment & Conviction      Lyndon B. Johnson
# 2790    Halsted     Ritter  Impeachment & Conviction        Calvin Coolidge
# 1574       West  Humphreys  Impeachment & Conviction        Franklin Pierce
# 2619       John  Pickering  Impeachment & Conviction      George Washington
#
#      Confirmation_Date_1
# 2656          1994-10-07
# 1400          1979-10-31
# 612           1978-08-11
# 2462          1968-06-06
# 2790          1929-02-15
# 1574          1853-03-26
# 2619          1795-02-11

# %%
df[df.Termination_1.str.contains("Recess", na=False)][['Last_Name','Termination_1','Appointing_President_1','Recess_Appointment_Date_1']].sort_values(by='Recess_Appointment_Date_1', ascending=False)
# Out:
#        Last_Name                     Termination_1 Appointing_President_1  \
# 1431        Heen  Recess Appointment-Not Confirmed           Jimmy Carter
# 2703  Rabinovitz  Recess Appointment-Not Confirmed      Lyndon B. Johnson
# 1040     Feikens  Recess Appointment-Not Confirmed   Dwight D. Eisenhower
# 1443      Henley  Recess Appointment-Not Confirmed   Dwight D. Eisenhower
# 1125    Friedman  Recess Appointment-Not Confirmed         Harry S Truman
# 71       Andrews  Recess Appointment-Not Confirmed         Harry S Truman
# 3229     Switzer  Recess Appointment-Not Confirmed         Harry S Truman
# 1380      Harper  Recess Appointment-Not Confirmed         Harry S Truman
# 2798     Roberts  Recess Appointment-Not Confirmed  Franklin D. Roosevelt
# 1650     Johnson  Recess Appointment-Not Confirmed         Herbert Hoover
# 3308      Tilson  Recess Appointment-Not Confirmed        Calvin Coolidge
# 2136    McCamant  Recess Appointment-Not Confirmed        Calvin Coolidge
# 587       Cheney  Recess Appointment-Not Confirmed        William H. Taft
# 1541      Howard  Recess Appointment-Not Confirmed        William H. Taft
# 3063       Sloan  Recess Appointment-Not Confirmed        William H. Taft
# 2693       Purdy  Recess Appointment-Not Confirmed     Theodore Roosevelt
# 1575     Hundley  Recess Appointment-Not Confirmed     Theodore Roosevelt
# 2910       Sater  Recess Appointment-Not Confirmed     Theodore Roosevelt
# 1021       Ewart  Recess Appointment-Not Confirmed       William McKinley
# 2180      McHugh  Recess Appointment-Not Confirmed       Grover Cleveland
# 3595       Winch  Recess Appointment-Not Confirmed          Ulysses Grant
# 3245      Tappan  Recess Appointment-Not Confirmed         Andrew Jackson
# 754    Creighton  Recess Appointment-Not Confirmed      John Quincy Adams
#
#      Recess_Appointment_Date_1
# 1431                1981-01-01
# 2703                1964-01-07
# 1040                1960-10-13
# 1443                1958-10-25
# 1125                1952-07-17
# 71                  1949-10-21
# 3229                1949-10-21
# 1380                1947-08-07
# 2798                1938-07-06
# 1650                1932-08-03
# 3308                1926-07-06
# 2136                1925-05-25
# 587                 1912-08-26
# 1541                1912-08-26
# 3063                1912-08-26
# 2693                1908-07-06
# 1575                1907-04-09
# 2910                1907-03-18
# 1021                1898-07-13
# 2180                1896-11-20
# 3595                1870-10-11
# 3245                1833-10-12
# 754                 1828-11-01

# %% [markdown]
# ### Gender & Race Breakdowns

# %%
df.groupby(by='Party_of_Appointing_President_1').Gender.value_counts(1)
# Out:
# Party_of_Appointing_President_1  Gender
# Democratic                       Male      0.836675
#                                  Female    0.163325
# Federalist                       Male      1.000000
# Jeffersonian Republican          Male      1.000000
# None (reassignment)              Male      1.000000
# Republican                       Male      0.914286
#                                  Female    0.085714
# Whig                             Male      1.000000
# Name: Gender, dtype: float64

# %%
df.groupby(by='Party_of_Appointing_President_1').Race_or_Ethnicity.value_counts(1)
# Out:
# Party_of_Appointing_President_1  Race_or_Ethnicity
# Democratic                       White                              0.843750
#                                  AfriAmerican                       0.095519
#                                  Hispanic                           0.040094
#                                  Asian American                     0.013561
#                                  AmeriIndian                        0.001769
#                                  AfriAmerican/Hispanic              0.001179
#                                  Asian American/Pacific Islander    0.001179
#                                  Hispanic/White                     0.001179
#                                  AfriAmerican/White                 0.000590
#                                  Asian American/Hispanic            0.000590
#                                  Asian American/White               0.000590
# Federalist                       White                              1.000000
# Jeffersonian Republican          White                              1.000000
# None (reassignment)              White                              1.000000
# Republican                       White                              0.932075
#                                  Hispanic                           0.030189
#                                  AfriAmerican                       0.028032
#                                  Asian American                     0.009164
#                                  Pacific Islander/White             0.000539
# Whig                             White                              1.000000
# Name: Race_or_Ethnicity, dtype: float64

# %% [markdown]
# ### Declined & Rejected Appointments

# %%
df[df['Other_Nominations-Recess_Appointments'].str.contains("(?i)Declined", na=False)][['Last_Name','Other_Nominations-Recess_Appointments','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#        Last_Name              Other_Nominations-Recess_Appointments  \
# 307      Boreman  Received recess appointment to U.S. Court of A...
# 1652     Johnson  Nominated to U.S. Customs Court, March 29, 194...
# 41        Allred  Received recess appointment to U.S. District C...
# 1160     Garrett  Received recess appointment to U.S. District C...
# 2138    McCarthy  Nominated to U.S. District Court for the Distr...
# 2467    Norcross  Received recess appointment to U.S. Court of A...
# 829          Day  Received recess appointment to U.S. District C...
# 864         Dick  Received recess appointment to U.S. District C...
# 3609      Withey  Nominated to U.S. District Court for the Weste...
# 1980  Livingston  Received recess appointment to U.S. District C...
# 632         Clay  Nominated to U.S. Circuit Court for the Fifth ...
# 1658     Johnson  Nominated to U.S. District Court for the Distr...
# 3054  Sitgreaves  Nominated to U.S. Circuit Court for the Fifth ...
# 201          Bee  Nominated to be chief judge of the U.S. Circui...
# 773      Cushing  Nominated to be Chief Justice of the Supreme C...
# 1635         Jay  Nominated to be Chief Justice of the Supreme C...
#
#      Appointing_President_1 Confirmation_Date_1
# 307    Dwight D. Eisenhower          1954-07-21
# 1652         Harry S Truman          1947-06-23
# 41    Franklin D. Roosevelt          1939-02-16
# 1160        Calvin Coolidge          1929-02-18
# 2138        Calvin Coolidge          1929-01-08
# 2467        Calvin Coolidge          1928-04-17
# 829        William McKinley          1899-02-28
# 864           Ulysses Grant          1872-06-07
# 3609        Abraham Lincoln          1863-03-11
# 1980       Thomas Jefferson          1806-12-17
# 632       George Washington          1796-12-27
# 1658      George Washington          1791-11-07
# 3054      George Washington          1790-12-20
# 201       George Washington          1790-06-14
# 773       George Washington          1789-09-26
# 1635      George Washington          1789-09-26

# %%
df[df['Other_Nominations-Recess_Appointments'].str.contains("(?i)Rejected", na=False)][['Last_Name','Other_Nominations-Recess_Appointments','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#        Last_Name              Other_Nominations-Recess_Appointments  \
# 3536       White  Nominated to U.S. District Court for the Easte...
# 308         Bork  Nominated to Supreme Court of the United State...
# 539     Carswell  Nominated to Supreme Court of the United State...
# 1418  Haynsworth  Nominated to Supreme Court of the United State...
# 2555      Parker  Nominated to Supreme Court of the United State...
# 3355      Turner  Nominated to U.S. District Court for the North...
# 2878    Rutledge  Nominated to be Chief Justice of the Supreme C...
# 71       Andrews  Nominated to U.S. District Court for the North...
# 2136    McCamant  Nominated to U.S. Court of Appeals for the Nin...
# 2798     Roberts  Nominated to U.S. District Court for the Weste...
# 3229     Switzer  Nominated to U.S. District Court for the South...
# 3245      Tappan  Nominated to U.S. District Court for the Distr...
#
#      Appointing_President_1 Confirmation_Date_1
# 3536           Barack Obama          2014-07-16
# 308           Ronald Reagan          1982-02-08
# 539    Dwight D. Eisenhower          1958-03-31
# 1418   Dwight D. Eisenhower          1957-04-04
# 2555        Calvin Coolidge          1925-12-14
# 3355    Rutherford B. Hayes          1880-12-20
# 2878      George Washington          1789-09-26
# 71           Harry S Truman                 NaT
# 2136        Calvin Coolidge                 NaT
# 2798  Franklin D. Roosevelt                 NaT
# 3229         Harry S Truman                 NaT
# 3245         Andrew Jackson                 NaT

# %%
df['Other_Nomination'] = df["Other_Nominations-Recess_Appointments"].str.findall(r"\b(nominated.*\d\d\d\d); .*", flags = re.I).dropna(0)
df['Other_Rejection'] = df["Other_Nominations-Recess_Appointments"].str.findall(r"\b(rejected.*\d\d\d\d).*", flags = re.I).dropna(0)
df[df['Other_Nominations-Recess_Appointments'].str.contains(r"rejected", na=False, flags = re.I)][['Last_Name','Other_Nomination','Other_Rejection','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#        Last_Name                                   Other_Nomination  \
# 3536       White  [Nominated to U.S. District Court for the East...
# 308         Bork  [Nominated to Supreme Court of the United Stat...
# 539     Carswell  [Nominated to Supreme Court of the United Stat...
# 1418  Haynsworth  [Nominated to Supreme Court of the United Stat...
# 2555      Parker  [Nominated to Supreme Court of the United Stat...
# 3355      Turner  [Nominated to U.S. District Court for the Nort...
# 2878    Rutledge  [Nominated to be Chief Justice of the Supreme ...
# 71       Andrews  [Nominated to U.S. District Court for the Nort...
# 2136    McCamant  [Nominated to U.S. Court of Appeals for the Ni...
# 2798     Roberts  [Nominated to U.S. District Court for the West...
# 3229     Switzer  [Nominated to U.S. District Court for the Sout...
# 3245      Tappan  [Nominated to U.S. District Court for the Dist...
#
#                                         Other_Rejection  \
# 3536  [rejected by Senate, October 5, 1999; Nominate...
# 308              [rejected by Senate, October 23, 1987]
# 539                 [rejected by Senate, April 8, 1970]
# 1418            [rejected by Senate, November 21, 1969]
# 2555                  [rejected by Senate, May 7, 1930]
# 3355                [rejected by Senate, April 2, 1879]
# 2878  [rejected by Senate, December 15, 1795; resign...
# 71    [rejected by Senate, August 9, 1950; resigned,...
# 2136  [rejected by Senate, March 17, 1926; resigned,...
# 2798  [rejected by Senate, February 6, 1939; resigne...
# 3229  [rejected by Senate, August 9, 1950; resigned,...
# 3245                 [rejected by Senate, May 29, 1834]
#
#      Appointing_President_1 Confirmation_Date_1
# 3536           Barack Obama          2014-07-16
# 308           Ronald Reagan          1982-02-08
# 539    Dwight D. Eisenhower          1958-03-31
# 1418   Dwight D. Eisenhower          1957-04-04
# 2555        Calvin Coolidge          1925-12-14
# 3355    Rutherford B. Hayes          1880-12-20
# 2878      George Washington          1789-09-26
# 71           Harry S Truman                 NaT
# 2136        Calvin Coolidge                 NaT
# 2798  Franklin D. Roosevelt                 NaT
# 3229         Harry S Truman                 NaT
# 3245         Andrew Jackson                 NaT

# %%
# df.apply(lambda x: x.str.contains(r"declined").any()).idxmax()
# df.apply(lambda x: x.str.startswith(r"Nominated").any()).idxmax()

# %%
df.loc[df.Party_of_Reappointing_President_1 != df.Party_of_Appointing_President_1][['Last_Name','Appointing_President_1','Reappointing_President_1','Recess_Appointment_Date_1','Nomination_Date_1','Confirmation_Date_1']].dropna().sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#      Last_Name Appointing_President_1 Reappointing_President_1  \
# 1287   Gregory     William J. Clinton           George W. Bush
#
#      Recess_Appointment_Date_1 Nomination_Date_1 Confirmation_Date_1
# 1287                2000-12-27        2001-05-09          2001-07-20

# %% [markdown]
# ### Professional Background

# %%
df.Professional_Career
# Out:
# 0       Law clerk, Hon. Marvin J. Garbis, U.S. Distric...
# 1       Law clerk, Hon. Thomas P. Griesa, U.S. Distric...
# 2         Private practice, Brooklyn, New York, 1910-1936
# 3       Private practice, Pittsburgh, Pennsylvania, 18...
# 4       U.S. Army private first class, 1946-1947; Priv...
# 5       Private practice, New Jersey, 1951-1954; Judge...
# 6       Private practice, Sangamon County, Illinois, 1...
# 7       Private practice, Hackensack, New Jersey, 1953...
# 8       Private practice, Muskogee, Oklahoma, 1912-191...
# 9       Private practice, Philadelphia, Pennsylvania, ...
# 10      Teacher, AmeriUnion Commission, Georgia, 1865-...
# 11      Private practice, Frankfort, Kentucky, 1810-18...
# 12      U.S. Army, 1861-1871; Merchant, 1871-1878; Pri...
# 13      Reginald Heber Smith fellow, Duval County Lega...
# 14      Law clerk, Hon. W. F. Spicer, Summit County [O...
# 15      Private practice, Carrollton, Georgia, 1876-19...
# 16      Research assistant, Columbia University Law Sc...
# 17      Assistant U.S. attorney, District of Columbia,...
# 18      Private practice, Rochester, New York, 1892-; ...
# 19      Law clerk, Hon. James Gulotta, Louisiana Court...
# 20      U.S. Army Reserve, 1986-1997; Private practice...
# 21      Private practice, San Jose, California, 1960-1...
# 22      Law clerk, Hon. Edwin Allen, Oregon Circuit Co...
# 23      Private practice, New Orleans, Louisiana, 1932...
# 24      Private practice, Cartersville, Georgia, 1892-...
# 25      U.S. Army second lieutenant pilot, Air Corps, ...
# 26      U.S. Army staff sergeant, 1943-1946; Deputy di...
# 27      Law clerk, Hon. James R. Nowlin, U.S. District...
# 28      U.S. Army captain, JAG Corps, 1960-1962; U.S. ...
# 29      U.S. Marine Corps major, 1942-1946; Private pr...
#                               ...
# 3664    Law clerk, Hon. James H. Payne, U.S. District ...
# 3665    Private practice, Boston, Massachusetts, 1930,...
# 3666    Law clerk, Hon. Diana Gribbon Motz, U.S. Court...
# 3667    Private practice, East St. Louis, Illinois, 19...
# 3668    Private practice, Modesto, California, 1909-19...
# 3669    U.S. Marine Corps, 1967-1970; Private practice...
# 3670    U.S. Marine Corps Reserve, 1960-1965; active d...
# 3671    Private practice, Fort Smith, Arkansas, 1886-1...
# 3672    Private practice, Norwalk, Ohio, 1934-1952; Ju...
# 3673    Private practice, Winter Haven, Florida, 1941-...
# 3674    Private practice, Valley City, North Dakota, 1...
# 3675    Private practice, Malvern, Arkansas, 1931-1939...
# 3676    Private practice, Pittsburgh, Pennsylvania, 18...
# 3677    U.S. Army, Infantry, 1942-1946; Private practi...
# 3678    Private practice, Evansville, Indiana, 1980-19...
# 3679    U.S. Army captain, 1962-1964; Law clerk, Hon. ...
# 3680    U.S. Army second lieutenant, World War I; Assi...
# 3681    Assistant state's attorney, Cook County, Illin...
# 3682    U.S. Air Force Reserve, 1970-1976; Law clerk i...
# 3683    Law clerk, U.S. District Court, District of Co...
# 3684    Staff attorney, Pima County [Arizona] Legal Ai...
# 3685    Assistant prosecutor, Macomb County, Michigan,...
# 3686    U.S. Army private, 1918-1919; Private practice...
# 3687    Private practice, Pittsburgh, Pennsylvania, 19...
# 3688    U.S. Naval Reserve lieutenant junior grade, 19...
# 3689    Law clerk, Hon. William C. Canby, U.S. Court o...
# 3690    Private practice, San Francisco, California, 1...
# 3691    U.S. Navy lieutenant, 1967-1969; Private pract...
# 3692    Law clerk, Hon. George C. Sweeney, U.S. Distri...
# 3693    Private practice, Toledo, Ohio, 1976-1999, 200...
# Name: Professional_Career, Length: 3694, dtype: object

# %%
df.Professional_Career = df.Professional_Career.astype(str)
Counter(" ".join(df.Professional_Career).lower().split()).most_common(60)
# pd.Series(' '.join(df.Professional_Career).lower().split()).value_counts().head(60)
# Out:
# [('of', 6835),
#  ('private', 4501),
#  ('practice,', 4463),
#  ('u.s.', 4128),
#  ('district', 2333),
#  ('the', 1967),
#  ('attorney,', 1937),
#  ('assistant', 1840),
#  ('new', 1830),
#  ('judge,', 1538),
#  ('court', 1476),
#  ('state', 1341),
#  ('court,', 1319),
#  ('law', 1275),
#  ('judicial', 1165),
#  ('attorney', 997),
#  ('county,', 964),
#  ('clerk,', 939),
#  ('and', 846),
#  ('for', 835),
#  ('hon.', 811),
#  ('member,', 778),
#  ('county', 772),
#  ('california,', 750),
#  ('justice,', 694),
#  ('united', 671),
#  ('law,', 651),
#  ('counsel,', 633),
#  ('states,', 615),
#  ('york,', 590),
#  ('circuit,', 590),
#  ('general,', 588),
#  ('army', 587),
#  ('university', 580),
#  ('pennsylvania,', 560),
#  ('department', 520),
#  ('york', 516),
#  ('supreme', 510),
#  ('city,', 497),
#  ('deputy', 491),
#  ('texas,', 491),
#  ('washington,', 482),
#  ('conference', 477),
#  ('city', 472),
#  ('special', 463),
#  ('illinois,', 430),
#  ('general', 397),
#  ('circuit', 395),
#  ('professor,', 384),
#  ('virginia,', 381),
#  ('ohio,', 361),
#  ('carolina,', 358),
#  ('jersey,', 356),
#  ('chief', 350),
#  ('florida,', 348),
#  ('division,', 342),
#  ('appeals', 341),
#  ('superior', 332),
#  ('army,', 324),
#  ('representative,', 320)]

# %%
###   BIGRAMS ???

# df.Professional_Career = df.Professional_Career.astype(str)
# Counter(" ".join(df.Professional_Career).lower().split()).most_common(60)
# pd.Series(' '.join(df.Professional_Career).lower().split()).value_counts().head(60)

df['Prof_Repeats'] = df.Professional_Career.str.findall(r"(?=(\b\w+\W+\w+\W+\w+))",flags=re.I).dropna(0)
# pd.Series(' '.join(df.Prof_Repeats).lower().split()).value_counts().head(60)
Counter(" ".join(df.Prof_Repeats).lower().split()).most_common(60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-226-00b05064235c> in <module>
#       7 df['Prof_Repeats'] = df.Professional_Career.str.findall(r"(?=(\b\w+\W+\w+\W+\w+))",flags=re.I).dropna(0)
#       8 # pd.Series(' '.join(df.Prof_Repeats).lower().split()).value_counts().head(60)
# ----> 9 Counter(" ".join(df.Prof_Repeats).lower().split()).most_common(60)
#
# TypeError: sequence item 0: expected str instance, list found

# %% [markdown]
# ### Education

# %%
lastreadlaw = [df[df['School_1'] == 'Read law'].Degree_Year_1.max(),
               df[df['School_2'] == 'Read law'].Degree_Year_3.max(), 
               df[df['School_3'] == 'Read law'].Degree_Year_3.max(),
               df[df['School_4'] == 'Read law'].Degree_Year_4.max(), 
               df[df['School_5'] == 'Read law'].Degree_Year_5.max()
              ]
lastreadlaw
# Out:
# [Timestamp('1934-01-01 00:00:00'),
#  Timestamp('1925-01-01 00:00:00'),
#  Timestamp('1930-01-01 00:00:00'),
#  Timestamp('1927-01-01 00:00:00'),
#  Timestamp('1910-01-01 00:00:00')]

# %%
allschool_df = df[['Full_Name','Appointing_President_1','Party_of_Appointing_President_1']]
allschool_df['Schl1'] = df.School_1 + '-777777777-' + df.Degree_1 + '-999999999-' + df.Degree_Year_1.astype(str)
allschool_df['Schl2'] = df.School_2 + '-777777777-' + df.Degree_2 + '-999999999-' + df.Degree_Year_2.astype(str)
allschool_df['Schl3'] = df.School_3 + '-777777777-' + df.Degree_3 + '-999999999-' + df.Degree_Year_3.astype(str)
allschool_df['Schl4'] = df.School_4 + '-777777777-' + df.Degree_4 + '-999999999-' + df.Degree_Year_4.astype(str)
allschool_df['Schl5'] = df.School_5 + '-777777777-' + df.Degree_5 + '-999999999-' + df.Degree_Year_5.astype(str)
# Out:
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
allschool_df.Degree_Number.replace(r'Schl',r'',regex=True,inplace=True)
allschool_df['Degree'] = allschool_df.School.str.extract('-777777777-(.*)-999999999-', expand=False)
allschool_df['Degree_Year'] = allschool_df.School.str.extract('.*-999999999-(.*)$', expand=False)
allschool_df['School'] = allschool_df.School.str.extract(r'(.*)-777777777-.*', expand=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-233-ede07a9250a4> in <module>
# ----> 1 allschool_df.Degree_Number.replace(r'Schl',r'',regex=True,inplace=True)
#       2 allschool_df['Degree'] = allschool_df.School.str.extract('-777777777-(.*)-999999999-', expand=False)
#       3 allschool_df['Degree_Year'] = allschool_df.School.str.extract('.*-999999999-(.*)$', expand=False)
#       4 allschool_df['School'] = allschool_df.School.str.extract(r'(.*)-777777777-.*', expand=False)
#
# C:\Program Files (x86)\Python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Degree_Number'

# %%
allschool_df = allschool_df.melt(id_vars =['Full_Name','Appointing_President_1','Party_of_Appointing_President_1'], value_vars =['Schl1','Schl2','Schl3','Schl4','Schl5'], var_name='Degree_Number', value_name='School')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-230-8ee69dbf8aaa> in <module>
# ----> 1 allschool_df = allschool_df.melt(id_vars =['Full_Name','Appointing_President_1','Party_of_Appointing_President_1'], value_vars =['Schl1','Schl2','Schl3','Schl4','Schl5'], var_name='Degree_Number', value_name='School')
#
# C:\Program Files (x86)\Python37-32\lib\site-packages\pandas\core\frame.py in melt(self, id_vars, value_vars, var_name, value_name, col_level)
#    6092         return melt(self, id_vars=id_vars, value_vars=value_vars,
#    6093                     var_name=var_name, value_name=value_name,
# -> 6094                     col_level=col_level)
#    6095
#    6096     # ----------------------------------------------------------------------
#
# C:\Program Files (x86)\Python37-32\lib\site-packages\pandas\core\reshape\melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level)
#      64                 raise KeyError("The following 'value_vars' are not present in"
#      65                                " the DataFrame: {missing}"
# ---> 66                                "".format(missing=list(missing)))
#      67         frame = frame.loc[:, id_vars + value_vars]
#      68     else:
#
# KeyError: "The following 'value_vars' are not present in the DataFrame: ['Schl1', 'Schl2', 'Schl3', 'Schl4', 'Schl5']"

# %%
allschool_df.head()
# Out:
#                Full_Name Appointing_President_1  \
# 0    Leslie Joyce Abrams           Barack Obama
# 1          Ronnie Abrams           Barack Obama
# 2     Matthew T. Abruzzo  Franklin D. Roosevelt
# 3  Marcus Wilson Acheson    Rutherford B. Hayes
# 4    William Marsh Acker          Ronald Reagan
#
#   Party_of_Appointing_President_1 Degree_Number  \
# 0                      Democratic             1
# 1                      Democratic             1
# 2                      Democratic             1
# 3                      Republican             1
# 4                      Republican             1
#
#                                               School Degree Degree_Year
# 0                                   Brown University   B.A.  1997-01-01
# 1                                 Cornell University   B.A.  1990-01-01
# 2                                Brooklyn Law School  LL.B.  1910-01-01
# 3  Washington College (now Washington and Jeffers...   B.A.  1845-01-01
# 4                        Birmingham-Southern College   B.A.  1949-01-01

# %%
allschool_df['School_Neat'] = allschool_df['School']
allschool_df.School_Neat.replace(r'.*\(now (.*)\)',r'\1',regex=True,inplace=True)
allschool_df.replace({'School_Neat':{
    'College of':'Cof',
    ' College':'',
    'University of':'Uof',
    ' University':'',
    ' Department':'',
    ' Faculty':'',
    ' School':'',
    ' Center':'',
    ' of Law':'',
    ' Law':'',
    ' of Jurisprudence':'',
    ' of Business':'',
    ' Business':'',
    ' Administration':'',
    ' Wharton':'',
    ' Gould':'',
    ', Boalt Hall':'',
    ', Paul M. Hebert':'',
    '-Kansas City':'',
    ' -- Newark':'',
    ' -- Camden':'',
    '  ':' '
}},regex=True,inplace=True)
allschool_df.School_Neat.replace(r'\s?Cof','',regex=True,inplace=True)
allschool_df.School_Neat.replace(r'\s?$','',regex=True,inplace=True)
allschool_df.School_Neat.replace(r',$','',regex=True,inplace=True)
allschool_df.School_Neat.value_counts().head(60)
# Out:
# Harvard                        467
# Yale                           260
# Uof Michigan                   175
# Columbia                       158
# Uof Texas                      152
# Uof Virginia                   151
# Georgetown                     136
# Uof Pennsylvania               117
# Stanford                       102
# Uof California, Berkeley        89
# New York                        88
# Princeton                       87
# Uof Florida                     78
# George Washington               74
# Uof Chicago                     70
# Cornell                         65
# Uof Alabama                     65
# Louisiana State                 63
# Uof Missouri                    58
# Northwestern                    58
# Uof Oklahoma                    55
# Uof Georgia                     53
# Rutgers                         53
# Duke                            51
# Vanderbilt                      51
# Uof Iowa                        50
# Uof California, Los Angeles     49
# Tulane                          49
# Boston                          48
# Uof Arkansas                    48
# Uof Southern California         48
# Uof Illinois                    48
# Uof South Carolina              47
# Uof North Carolina              46
# Fordham                         46
# Uof Minnesota                   43
# Uof Wisconsin                   42
# Uof Arizona                     41
# West Virginia                   41
# Howard                          39
# Uof Kansas                      39
# Temple                          38
# Uof Washington                  38
# Emory                           37
# Dartmouth                       36
# Uof Notre Dame                  35
# Washington and Lee              35
# Uof Mississippi                 34
# Uof Cincinnati                  30
# Uof Tennessee                   30
# Ohio State                      29
# Uof Kentucky                    29
# Notre Dame                      29
# Dickinson                       28
# Uof Pittsburgh                  28
# Syracuse                        26
# St. Louis                       26
# Marquette                       25
# Uof Puerto Rico                 25
# Wake Forest                     25
# Name: School_Neat, dtype: int64

# %%
allschool_df.School_Neat.value_counts().head(30).plot(kind='barh', figsize=(18, 5))

# %%
allschool_df.groupby(by='Party_of_Appointing_President_1').School_Neat.value_counts(1)
# Out:
# Party_of_Appointing_President_1  School_Neat
# Democratic                       Harvard                                  0.076463
#                                  Yale                                     0.044548
#                                  Uof Texas                                0.028590
#                                  Columbia                                 0.027593
#                                  Georgetown                               0.022939
#                                  Uof Michigan                             0.020944
#                                  Uof Virginia                             0.020612
#                                  Uof Florida                              0.017287
#                                  Uof California, Berkeley                 0.016290
#                                  Stanford                                 0.015957
#                                  Uof Pennsylvania                         0.014628
#                                  New York                                 0.013630
#                                  Louisiana State                          0.013298
#                                  Uof Chicago                              0.012301
#                                  Uof Missouri                             0.012301
#                                  George Washington                        0.011303
#                                  Boston                                   0.010971
#                                  Princeton                                0.010306
#                                  Howard                                   0.009973
#                                  Uof Oklahoma                             0.009973
#                                  Rutgers                                  0.009641
#                                  Uof Georgia                              0.009309
#                                  Cornell                                  0.008976
#                                  Uof Arkansas                             0.008976
#                                  Fordham                                  0.008644
#                                  Uof California, Los Angeles              0.008644
#                                  Vanderbilt                               0.008644
#                                  Uof Alabama                              0.008311
#                                  Uof South Carolina                       0.007979
#                                  Uof Wisconsin                            0.007979
#                                                                             ...
# Republican                       Uof Puerto Rico of Public                0.000305
#                                  Uof Richmond                             0.000305
#                                  Uof Scranton                             0.000305
#                                  Uof South Florida                        0.000305
#                                  Uof Southern Mississippi                 0.000305
#                                  Uof Texas at El Paso                     0.000305
#                                  Uof Texas, LBJ of Public Affairs         0.000305
#                                  Uof Vermont                              0.000305
#                                  Uof Western Kentucky                     0.000305
#                                  Uof Western Ontario                      0.000305
#                                  Uof Wisconsin, Milwaukee                 0.000305
#                                  Uof the Pacific                          0.000305
#                                  Ursinus                                  0.000305
#                                  Utah State                               0.000305
#                                  Washington, Chestertown, Maryland        0.000305
#                                  West Virginia Institute of Technology    0.000305
#                                  West Virginia Wesleyan                   0.000305
#                                  Western Kentucky                         0.000305
#                                  Western Michigan                         0.000305
#                                  Western Michigan, Honors                 0.000305
#                                  Western State Colorado                   0.000305
#                                  Westfield State Teachers                 0.000305
#                                  Westminster, Fulton, Missouri            0.000305
#                                  Whitworth                                0.000305
#                                  Wichita State                            0.000305
#                                  Wilkes                                   0.000305
#                                  William Carey                            0.000305
#                                  Yeshiva, Benjamin N. Cardozo             0.000305
# Whig                             Harvard                                  0.800000
#                                  Columbia                                 0.200000
# Name: School_Neat, Length: 991, dtype: float64

# %%
df.Degree_1.value_counts().head()
# Out:
# B.A.      1323
# A.B.       715
# LL.B.      416
# B.S.       387
# B.B.A.      53
# Name: Degree_1, dtype: int64

# %%
allschool_df.to_csv('allschool.csv', index=False)
# Out:
#       Degree_1 Degree_2 Degree_3 Degree_4 Degree_5  variable  \
# 0         B.A.     J.D.      NaN      NaN      NaN  School_1
# 1         B.A.     J.D.      NaN      NaN      NaN  School_1
# 2        LL.B.      NaN      NaN      NaN      NaN  School_1
# 3         B.A.      NaN      NaN      NaN      NaN  School_1
# 4         B.A.    LL.B.      NaN      NaN      NaN  School_1
# 5        LL.B.      NaN      NaN      NaN      NaN  School_1
# 6         B.S.     J.D.      NaN      NaN      NaN  School_1
# 7         J.D.      NaN      NaN      NaN      NaN  School_1
# 8        LL.B.      NaN      NaN      NaN      NaN  School_1
# 9         B.S.    LL.B.     M.A.      NaN      NaN  School_1
# 10        B.A.      NaN      NaN      NaN      NaN  School_1
# 11         NaN      NaN      NaN      NaN      NaN  School_1
# 12         NaN      NaN      NaN      NaN      NaN  School_1
# 13        B.S.     J.D.      NaN      NaN      NaN  School_1
# 14        B.S.     J.D.      NaN      NaN      NaN  School_1
# 15        A.B.      NaN      NaN      NaN      NaN  School_1
# 16        A.B.    LL.B.      NaN      NaN      NaN  School_1
# 17       LL.B.    LL.M.      NaN      NaN      NaN  School_1
# 18        B.L.      NaN      NaN      NaN      NaN  School_1
# 19        B.A.     J.D.      NaN      NaN      NaN  School_1
# 20        B.A.     J.D.    LL.M.      NaN      NaN  School_1
# 21        B.A.     J.D.      NaN      NaN      NaN  School_1
# 22        B.S.     M.A.     J.D.      NaN      NaN  School_1
# 23       LL.B.      NaN      NaN      NaN      NaN  School_1
# 24         NaN      NaN      NaN      NaN      NaN  School_1
# 25        B.A.     J.D.      NaN      NaN      NaN  School_1
# 26        B.A.    LL.B.      NaN      NaN      NaN  School_1
# 27        B.A.     J.D.      NaN      NaN      NaN  School_1
# 28        B.A.    LL.B.      NaN      NaN      NaN  School_1
# 29        B.A.     J.D.      NaN      NaN      NaN  School_1
# ...        ...      ...      ...      ...      ...       ...
# 18440     B.A.     J.D.      NaN      NaN      NaN  School_5
# 18441     A.B.    LL.B.      NaN      NaN      NaN  School_5
# 18442     B.A.     J.D.      NaN      NaN      NaN  School_5
# 18443     B.S.     J.D.      NaN      NaN      NaN  School_5
# 18444    LL.B.     J.D.      NaN      NaN      NaN  School_5
# 18445     B.A.     J.D.    LL.M.      NaN      NaN  School_5
# 18446      NaN     B.A.     J.D.      NaN      NaN  School_5
# 18447      NaN  Litt.B.      NaN      NaN      NaN  School_5
# 18448     A.B.    LL.B.      NaN      NaN      NaN  School_5
# 18449     A.B.    LL.B.      NaN      NaN      NaN  School_5
# 18450    LL.B.      NaN      NaN      NaN      NaN  School_5
# 18451    LL.B.      NaN      NaN      NaN      NaN  School_5
# 18452     A.B.      NaN      NaN      NaN      NaN  School_5
# 18453     A.B.    LL.B.      NaN      NaN      NaN  School_5
# 18454     B.A.     J.D.      NaN      NaN      NaN  School_5
# 18455     A.B.    LL.B.      NaN      NaN      NaN  School_5
# 18456     B.A.    LL.B.      NaN      NaN      NaN  School_5
# 18457     B.A.     M.A.     J.D.      NaN      NaN  School_5
# 18458     B.S.     J.D.      NaN      NaN      NaN  School_5
# 18459     B.A.    LL.B.      NaN      NaN      NaN  School_5
# 18460     A.A.     B.A.     J.D.      NaN      NaN  School_5
# 18461     B.S.     J.D.      NaN      NaN      NaN  School_5
# 18462     B.A.    LL.B.      NaN      NaN      NaN  School_5
# 18463     B.A.    LL.B.      NaN      NaN      NaN  School_5
# 18464     B.A.     J.D.      NaN      NaN      NaN  School_5
# 18465     B.A.     J.D.      NaN      NaN      NaN  School_5
# 18466     A.B.     J.D.      NaN      NaN      NaN  School_5
# 18467     B.A.     J.D.      NaN      NaN      NaN  School_5
# 18468     A.B.    LL.B.      NaN      NaN      NaN  School_5
# 18469     B.A.     J.D.      NaN      NaN      NaN  School_5
#
#                                                    value  \
# 0                                       Brown University
# 1                                     Cornell University
# 2                                    Brooklyn Law School
# 3      Washington College (now Washington and Jeffers...
# 4                            Birmingham-Southern College
# 5                        Rutgers School of Law -- Newark
# 6                                   Marquette University
# 7                        Rutgers School of Law -- Newark
# 8                      University of Michigan Law School
# 9                                      Temple University
# 10                                          Yale College
# 11                                              Read law
# 12                                              Read law
# 13                                Florida A&M University
# 14                        Bowling Green State University
# 15                               Bowdon College, Georgia
# 16                                  Princeton University
# 17     Georgetown College Law School (now Georgetown ...
# 18                                    Cornell University
# 19                          University of North Carolina
# 20                                   Bridgewater College
# 21                    University of California, Berkeley
# 22                                  University of Oregon
# 23           Loyola University New Orleans School of Law
# 24                                              Read law
# 25                              Ohio Northern University
# 26                     University of Southern California
# 27                Trinity University, San Antonio, Texas
# 28                                 University of Alabama
# 29                              University of Pittsburgh
# ...                                                  ...
# 18440                                                NaN
# 18441                                                NaN
# 18442                                                NaN
# 18443                                                NaN
# 18444                                                NaN
# 18445                                                NaN
# 18446                                                NaN
# 18447                                                NaN
# 18448                                                NaN
# 18449                                                NaN
# 18450                                                NaN
# 18451                                                NaN
# 18452                                                NaN
# 18453                                                NaN
# 18454                                                NaN
# 18455                                                NaN
# 18456                                                NaN
# 18457                                                NaN
# 18458                                                NaN
# 18459                                                NaN
# 18460                                                NaN
# 18461                                                NaN
# 18462                                                NaN
# 18463                                                NaN
# 18464                                                NaN
# 18465                                                NaN
# 18466                                                NaN
# 18467                                                NaN
# 18468                                                NaN
# 18469                                                NaN
#
#                             cleaned
# 0                             Brown
# 1                           Cornell
# 2                          Brooklyn
# 3          Washington and Jefferson
# 4               Birmingham-Southern
# 5                           Rutgers
# 6                         Marquette
# 7                           Rutgers
# 8                      Uof Michigan
# 9                            Temple
# 10                             Yale
# 11                         Read law
# 12                         Read law
# 13                      Florida A&M
# 14              Bowling Green State
# 15                  Bowdon, Georgia
# 16                        Princeton
# 17                       Georgetown
# 18                          Cornell
# 19               Uof North Carolina
# 20                      Bridgewater
# 21         Uof California, Berkeley
# 22                       Uof Oregon
# 23              Loyola  New Orleans
# 24                         Read law
# 25                    Ohio Northern
# 26          Uof Southern California
# 27     Trinity , San Antonio, Texas
# 28                      Uof Alabama
# 29                   Uof Pittsburgh
# ...                             ...
# 18440                           NaN
# 18441                           NaN
# 18442                           NaN
# 18443                           NaN
# 18444                           NaN
# 18445                           NaN
# 18446                           NaN
# 18447                           NaN
# 18448                           NaN
# 18449                           NaN
# 18450                           NaN
# 18451                           NaN
# 18452                           NaN
# 18453                           NaN
# 18454                           NaN
# 18455                           NaN
# 18456                           NaN
# 18457                           NaN
# 18458                           NaN
# 18459                           NaN
# 18460                           NaN
# 18461                           NaN
# 18462                           NaN
# 18463                           NaN
# 18464                           NaN
# 18465                           NaN
# 18466                           NaN
# 18467                           NaN
# 18468                           NaN
# 18469                           NaN
#
# [18470 rows x 8 columns]

# %%
df[df['School_1'].isin(['Harvard University', 'Yale University', 'Brown University', 'Columbia University', 'Princeton University'])]

# %% [markdown]
# # Confirmation Dates

# %%
df['Confirmation_Duration_Total'] = df.Confirmation_Date_1 - df.Nomination_Date_1
df.Confirmation_Duration_Total.sort_values(ascending=False).head(60)
# Out:
# 1081   639 days
# 1142   540 days
# 3577   539 days
# 2314   531 days
# 1512   524 days
# 956    484 days
# 2011   479 days
# 3019   479 days
# 739    479 days
# 1788   463 days
# 1954   460 days
# 2542   447 days
# 2191   444 days
# 3412   441 days
# 2148   437 days
# 755    432 days
# 1609   423 days
# 3666   417 days
# 1933   415 days
# 220    413 days
# 861    409 days
# 236    408 days
# 3193   403 days
# 2362   400 days
# 1433   392 days
# 2099   391 days
# 1337   388 days
# 22     386 days
# 2578   383 days
# 2856   382 days
# 3565   376 days
# 1133   365 days
# 2646   365 days
# 118    355 days
# 3235   355 days
# 804    350 days
# 2940   339 days
# 2163   334 days
# 311    334 days
# 2804   330 days
# 2825   330 days
# 688    323 days
# 643    317 days
# 3368   317 days
# 2214   317 days
# 766    317 days
# 2850   316 days
# 656    316 days
# 339    315 days
# 3083   314 days
# 1340   313 days
# 1303   312 days
# 385    312 days
# 1726   312 days
# 2120   311 days
# 474    308 days
# 3006   307 days
# 2916   307 days
# 3395   307 days
# 3327   307 days
# Name: Confirmation_Duration_Total, dtype: timedelta64[ns]

# %%
timedelta

# %%
# df[df['date'] >='20140905'].head()

# %%
# df[(df['sku'].str.contains('B1-531')) & (df['quantity']>40)].sort(columns=['quantity','name'],ascending=[0,1])
