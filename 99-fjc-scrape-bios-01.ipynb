# %%
import pandas as pd
import numpy as np
import requests
# import json
# import re
# import os
# import time
from bs4 import BeautifulSoup

# %%
# url = "https://www.fjc.gov/history/courts/u.s.-courts-appeals-and-federal-judiciary"
# response = requests.get(url)
# doc = BeautifulSoup(response.text)

# %%
my_url = "https://www.fjc.gov/history/courts/u.s.-courts-appeals-and-federal-judiciary"
raw_html = requests.get(my_url).content
soup_doc = BeautifulSoup(raw_html, "html.parser")
print(type(soup_doc))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
### TEST VIEWS OF DATA
# raw_html
# print(soup_doc)
print(soup_doc.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="no-js ie iem7" lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="no-js ie lt-ie9 lt-ie8 lt-ie7" lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="no-js ie lt-ie9 lt-ie8" lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="no-js ie lt-ie9" lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><html class="no-js ie" lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#"><![endif]-->
# <!--[if !IE]><!-->
# ...

# %%
soup_doc.find_all(class_='ctools-jump-menu-select')[0]
# Out:
# <select class="ctools-jump-menu-select ctools-jump-menu-change form-select" id="edit-jump" name="jump"><option selected="selected" value="">- Choose Circuit -</option><option value="dc76793329e10b09f6cef0ffc64fc3e6::/history/courts/u.s.-court-appeals-first-circuit">
#           First Circuit  </option><option value="6d29e62c38bc2ee554069c9516d688d1::/history/courts/u.s.-court-appeals-second-circuit">
#           Second Circuit  </option><option value="6f14110eb412081c89d080983614fe7a::/history/courts/u.s.-court-appeals-third-circuit">
#           Third Circuit  </option><option value="275aff6b73c6014aff6ffd26b14afeaf::/history/courts/u.s.-court-appeals-fourth-circuit">
#           Fourth Circuit  </option><option value="8650a004dea9f826b26026fd71e87aba::/history/courts/u.s.-court-appeals-fifth-circuit">
#           Fifth Circuit  </option><option value="7c2a69e28822a7e411b4800c13dee768::/history/courts/u.s.-court-appeals-sixth-circuit">
# ...

# %%
#edit-jump > option:nth-child(4)

# %%
dropdown = soup_doc.find_all(class_='ctools-jump-menu-select')[0]
# dropdown.find('option')
elements = []
for selection in dropdown:
    district = selection.text
    selec = selection(.)value
    print(selec)
#     elem = selection.find('option')
#     elements.append(elem)
# elements
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
get_attribute_list
