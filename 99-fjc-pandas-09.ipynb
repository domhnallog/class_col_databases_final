# %% [markdown]
# # Imports & File Load

# %%
import pandas as pd
import numpy as np
import pandas_profiling
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42
# import requests
# import json
import re
# import os
# import time
import datetime
# from bs4 import BeautifulSoup
from collections import Counter
# %matplotlib inline

# %%
df = pd.read_csv("sources/judges_careersCurrentFirst.csv")
df.head(3)
# Out:
#        nid   jid  Last Name First Name Middle Name Suffix  Birth Month  \
# 0  1393126  3258  Scarburgh     George      Parker                 2.0
# 1  1393041  3241  Gilchrist       John       James                 2.0
# 2  1393146  3262     Loring     Edward      Greely                 1.0
#
#    Birth Day Birth Year       Birth City  ... Degree (3)  Degree Year (3)  \
# 0       11.0       1807  Accomack County  ...        NaN              NaN
# 1       16.0       1809          Medford  ...        NaN              NaN
# 2       28.0       1802           Boston  ...        NaN              NaN
#
#    School (4)  Degree (4) Degree Year (4) School (5) Degree (5)  \
# 0         NaN         NaN             NaN        NaN        NaN
# 1         NaN         NaN             NaN        NaN        NaN
# 2         NaN         NaN             NaN        NaN        NaN
#
#   Degree Year (5)                                Professional Career  \
# 0             NaN  Private practice, Accomack County, Virginia, 1...
# 1             NaN  Private practice, Charlestown, New Hampshire, ...
# 2             NaN  Private practice and master in chancery, Suffo...
#
#   Other Nominations/Recess Appointments
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
# [3 rows x 201 columns]

# %% [markdown]
# # File Investigation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3694 entries, 0 to 3693
# Columns: 201 entries, nid to Other Nominations/Recess Appointments
# dtypes: float64(56), int64(2), object(143)
# memory usage: 3.6+ MB

# %%
original_size = df.memory_usage().sum()
original_size
# Out:
# 3827024

# %%
# df.dtypes
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3694 entries, 0 to 3693
# Data columns (total 201 columns):
# nid                                      int64
# jid                                      int64
# Last Name                                object
# First Name                               object
# Middle Name                              object
# Suffix                                   object
# Birth Month                              float64
# Birth Day                                float64
# Birth Year                               object
# Birth City                               object
# Birth State                              object
# Death Month                              float64
# Death Day                                float64
# Death Year                               float64
# Death City                               object
# Death State                              object
# Gender                                   object
# Race or Ethnicity                        object
# Court Type (1)                           object
# Court Name (1)                           object
# Appointment Title (1)                    object
# Appointing President (1)                 object
# Party of Appointing President (1)        object
# Reappointing President (1)               object
# Party of Reappointing President (1)      object
# ABA Rating (1)                           object
# Seat ID (1)                              object
# Statute Authorizing New Seat (1)         object
# Recess Appointment Date (1)              object
# Nomination Date (1)                      object
# Committee Referral Date (1)              object
# Hearing Date (1)                         object
# Judiciary Committee Action (1)           object
# Committee Action Date (1)                object
# Senate Vote Type (1)                     object
# Ayes/Nays (1)                            object
# Confirmation Date (1)                    object
# Commission Date (1)                      object
# Service as Chief Judge, Begin (1)        float64
# Service as Chief Judge, End (1)          float64
# 2nd Service as Chief Judge, Begin (1)    float64
# 2nd Service as Chief Judge, End (1)      float64
# Senior Status Date (1)                   object
# Termination (1)                          object
# Termination Date (1)                     object
# Court Type (2)                           object
# Court Name (2)                           object
# Appointment Title (2)                    object
# Appointing President (2)                 object
# Party of Appointing President (2)        object
# Reappointing President (2)               float64
# Party of Reappointing President (2)      float64
# ABA Rating (2)                           object
# Seat ID (2)                              object
# Statute Authorizing New Seat (2)         object
# Recess Appointment Date (2)              object
# Nomination Date (2)                      object
# Committee Referral Date (2)              object
# Hearing Date (2)                         object
# Judiciary Committee Action (2)           object
# Committee Action Date (2)                object
# Senate Vote Type (2)                     object
# Ayes/Nays (2)                            object
# Confirmation Date (2)                    object
# Commission Date (2)                      object
# Service as Chief Judge, Begin (2)        float64
# Service as Chief Judge, End (2)          float64
# 2nd Service as Chief Judge, Begin (2)    float64
# 2nd Service as Chief Judge, End (2)      float64
# Senior Status Date (2)                   object
# Termination (2)                          object
# Termination Date (2)                     object
# Court Type (3)                           object
# Court Name (3)                           object
# Appointment Title (3)                    object
# Appointing President (3)                 object
# Party of Appointing President (3)        object
# Reappointing President (3)               float64
# Party of Reappointing President (3)      float64
# ABA Rating (3)                           object
# Seat ID (3)                              object
# Statute Authorizing New Seat (3)         object
# Recess Appointment Date (3)              object
# Nomination Date (3)                      object
# Committee Referral Date (3)              object
# Hearing Date (3)                         object
# Judiciary Committee Action (3)           object
# Committee Action Date (3)                object
# Senate Vote Type (3)                     object
# Ayes/Nays (3)                            object
# Confirmation Date (3)                    object
# Commission Date (3)                      object
# Service as Chief Judge, Begin (3)        float64
# Service as Chief Judge, End (3)          float64
# 2nd Service as Chief Judge, Begin (3)    float64
# 2nd Service as Chief Judge, End (3)      float64
# Senior Status Date (3)                   object
# Termination (3)                          object
# Termination Date (3)                     object
# Court Type (4)                           object
# Court Name (4)                           object
# Appointment Title (4)                    object
# Appointing President (4)                 object
# Party of Appointing President (4)        object
# Reappointing President (4)               float64
# Party of Reappointing President (4)      float64
# ABA Rating (4)                           float64
# Seat ID (4)                              object
# Statute Authorizing New Seat (4)         object
# Recess Appointment Date (4)              object
# Nomination Date (4)                      object
# Committee Referral Date (4)              object
# Hearing Date (4)                         float64
# Judiciary Committee Action (4)           object
# Committee Action Date (4)                object
# Senate Vote Type (4)                     object
# Ayes/Nays (4)                            object
# Confirmation Date (4)                    object
# Commission Date (4)                      object
# Service as Chief Judge, Begin (4)        float64
# Service as Chief Judge, End (4)          float64
# 2nd Service as Chief Judge, Begin (4)    float64
# 2nd Service as Chief Judge, End (4)      float64
# Senior Status Date (4)                   float64
# Termination (4)                          object
# Termination Date (4)                     object
# Court Type (5)                           object
# Court Name (5)                           object
# Appointment Title (5)                    object
# Appointing President (5)                 object
# Party of Appointing President (5)        object
# Reappointing President (5)               float64
# Party of Reappointing President (5)      float64
# ABA Rating (5)                           float64
# Seat ID (5)                              object
# Statute Authorizing New Seat (5)         object
# Recess Appointment Date (5)              object
# Nomination Date (5)                      object
# Committee Referral Date (5)              object
# Hearing Date (5)                         object
# Judiciary Committee Action (5)           object
# Committee Action Date (5)                float64
# Senate Vote Type (5)                     float64
# Ayes/Nays (5)                            object
# Confirmation Date (5)                    float64
# Commission Date (5)                      float64
# Service as Chief Judge, Begin (5)        float64
# Service as Chief Judge, End (5)          float64
# 2nd Service as Chief Judge, Begin (5)    float64
# 2nd Service as Chief Judge, End (5)      float64
# Senior Status Date (5)                   float64
# Termination (5)                          object
# Termination Date (5)                     object
# Court Type (6)                           object
# Court Name (6)                           object
# Appointment Title (6)                    object
# Appointing President (6)                 object
# Party of Appointing President (6)        object
# Reappointing President (6)               float64
# Party of Reappointing President (6)      float64
# ABA Rating (6)                           float64
# Seat ID (6)                              object
# Statute Authorizing New Seat (6)         object
# Recess Appointment Date (6)              object
# Nomination Date (6)                      object
# Committee Referral Date (6)              object
# Hearing Date (6)                         object
# Judiciary Committee Action (6)           object
# Committee Action Date (6)                float64
# Senate Vote Type (6)                     float64
# Ayes/Nays (6)                            object
# Confirmation Date (6)                    float64
# Commission Date (6)                      float64
# Service as Chief Judge, Begin (6)        float64
# Service as Chief Judge, End (6)          float64
# 2nd Service as Chief Judge, Begin (6)    float64
# 2nd Service as Chief Judge, End (6)      float64
# Senior Status Date (6)                   float64
# Termination (6)                          object
# Termination Date (6)                     object
# Other Federal Judicial Service (1)       object
# Other Federal Judicial Service (2)       object
# Other Federal Judicial Service (3)       object
# Other Federal Judicial Service (4)       object
# School (1)                               object
# Degree (1)                               object
# Degree Year (1)                          object
# School (2)                               object
# Degree (2)                               object
# Degree Year (2)                          object
# School (3)                               object
# Degree (3)                               object
# Degree Year (3)                          object
# School (4)                               object
# Degree (4)                               object
# Degree Year (4)                          float64
# School (5)                               object
# Degree (5)                               object
# Degree Year (5)                          float64
# Professional Career                      object
# Other Nominations/Recess Appointments    object
# dtypes: float64(56), int64(2), object(143)
# memory usage: 3.6+ MB

# %% [markdown]
# # Basic Clean
# - make easy column headers
# - remove the circa abbreviation everywhere
# - convert separated birth/death info to united field
# - convert all string dates into datetime
# - convert year-only dates into datetime
# - convert repeated strings to categories

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace('/', '_n_')
df.columns = df.columns.str.replace('\(|\)|,', '')
df.replace('ca. ','',regex=True,inplace=True)

# %%
df['Birth_Month'] = pd.to_numeric(df['Birth_Month'], errors='coerce').fillna(value=9).astype(int)
df['Birth_Day'] = pd.to_numeric(df['Birth_Day'], errors='coerce').fillna(value=30).astype(int)
df['Birth_Year'] = pd.to_numeric(df['Birth_Year'], errors='coerce').fillna(value=1677).astype(int)
df['Birth_Date'] = df.Birth_Year.map(str).astype(str).str.zfill(4) + '-' + df.Birth_Month.map(str).astype(str).str.zfill(2) + '-' + df.Birth_Day.map(str).astype(str).str.zfill(2)
df['Death_Month'] = pd.to_numeric(df['Death_Month'], errors='coerce').fillna(value=9).astype(int)
df['Death_Day'] = pd.to_numeric(df['Death_Day'], errors='coerce').fillna(value=30).astype(int)
df['Death_Year'] = pd.to_numeric(df['Death_Year'], errors='coerce').fillna(value=1677).astype(int)
df['Death_Date'] = df.Death_Year.map(str).astype(str).str.zfill(4) + '-' + df.Death_Month.map(str).astype(str).str.zfill(2) + '-' + df.Death_Day.map(str).astype(str).str.zfill(2)

# %%
df.Death_Date.head()
# Out:
# 0    1879-12-21
# 1    1858-04-29
# 2    1890-06-19
# 3    1907-12-27
# 4    1905-04-10
# Name: Death_Date, dtype: object

# %%
forceDT = [
    'Birth_Date','Death_Date',
    'Recess_Appointment_Date_1','Nomination_Date_1','Committee_Referral_Date_1','Hearing_Date_1','Committee_Action_Date_1','Confirmation_Date_1','Commission_Date_1','Service_as_Chief_Judge_Begin_1','Service_as_Chief_Judge_End_1','2nd_Service_as_Chief_Judge_Begin_1','2nd_Service_as_Chief_Judge_End_1','Senior_Status_Date_1','Termination_Date_1',
    'Recess_Appointment_Date_2','Nomination_Date_2','Committee_Referral_Date_2','Hearing_Date_2','Committee_Action_Date_2','Confirmation_Date_2','Commission_Date_2','Service_as_Chief_Judge_Begin_2','Service_as_Chief_Judge_End_2','2nd_Service_as_Chief_Judge_Begin_2','2nd_Service_as_Chief_Judge_End_2','Senior_Status_Date_2','Termination_Date_2',
    'Recess_Appointment_Date_3','Nomination_Date_3','Committee_Referral_Date_3','Hearing_Date_3','Committee_Action_Date_3','Confirmation_Date_3','Commission_Date_3','Service_as_Chief_Judge_Begin_3','Service_as_Chief_Judge_End_3','2nd_Service_as_Chief_Judge_Begin_3','2nd_Service_as_Chief_Judge_End_3','Senior_Status_Date_3','Termination_Date_3',
    'Recess_Appointment_Date_4','Nomination_Date_4','Committee_Referral_Date_4','Hearing_Date_4','Committee_Action_Date_4','Confirmation_Date_4','Commission_Date_4','Service_as_Chief_Judge_Begin_4','Service_as_Chief_Judge_End_4','2nd_Service_as_Chief_Judge_Begin_4','2nd_Service_as_Chief_Judge_End_4','Senior_Status_Date_4','Termination_Date_4',
    'Recess_Appointment_Date_5','Nomination_Date_5','Committee_Referral_Date_5','Hearing_Date_5','Committee_Action_Date_5','Confirmation_Date_5','Commission_Date_5','Service_as_Chief_Judge_Begin_5','Service_as_Chief_Judge_End_5','2nd_Service_as_Chief_Judge_Begin_5','2nd_Service_as_Chief_Judge_End_5','Senior_Status_Date_5','Termination_Date_5',
    'Recess_Appointment_Date_6','Nomination_Date_6','Committee_Referral_Date_6','Hearing_Date_6','Committee_Action_Date_6','Confirmation_Date_6','Commission_Date_6','Service_as_Chief_Judge_Begin_6','Service_as_Chief_Judge_End_6','2nd_Service_as_Chief_Judge_Begin_6','2nd_Service_as_Chief_Judge_End_6','Senior_Status_Date_6','Termination_Date_6'
]
df[forceDT] = df[forceDT].apply(pd.to_datetime)

# %%
df['Degree_Year_1'] = pd.to_datetime(df['Degree_Year_1'],format='%Y', errors='coerce')
df['Degree_Year_2'] = pd.to_datetime(df['Degree_Year_2'],format='%Y', errors='coerce')
df['Degree_Year_3'] = pd.to_datetime(df['Degree_Year_3'],format='%Y', errors='coerce')
df['Degree_Year_4'] = pd.to_datetime(df['Degree_Year_4'],format='%Y', errors='coerce')
df['Degree_Year_5'] = pd.to_datetime(df['Degree_Year_5'],format='%Y', errors='coerce')

# %%
df['Full_Name'] = df.First_Name + ' ' + df.Middle_Name + ' ' + df.Last_Name + ', ' + df.Suffix
df.Full_Name.replace(r'\s{2,4}',' ',regex=True,inplace=True)
df.Full_Name.replace(r', $','',regex=True,inplace=True)
df.Full_Name.head(30)
# Out:
# 0          George Parker Scarburgh
# 1             John James Gilchrist
# 2             Edward Greely Loring
# 3     John Chandler Bancroft Davis
# 4                  Lawrence Weldon
# 5           George Wesley Atkinson
# 6                        James Hay
# 7            William Raymond Green
# 8             Joseph Warren Madden
# 9           Isaac Newton Blackford
# 10                    James Hughes
# 11             Charles Bowen Howry
# 12              George Eddy Downey
# 13              John McKenzie Moss
# 14      Benjamin Horsley Littleton
# 15            James Randall Durfee
# 16                    Joseph Casey
# 17            Charles Daniel Drake
# 18        William Adams Richardson
# 19             Charles Cooper Nott
# 20          Stanton Judkins Peelle
# 21          Edward Kernan Campbell
# 22           Fenton Whitlock Booth
# 23            Richard Smith Whaley
# 24                    David Wilmot
# 25                 Samuel Milligan
# 26                      John Davis
# 27           Nicholas John Sinnott
# 28          Thomas Sutler Williams
# 29              George Evan Howell
# Name: Full_Name, dtype: object

# %%
df.memory_usage().sum() / original_size * 100
# Out:
# 118.14652847748015

# %%
# forceCat = [
#     'Gender','Race_or_Ethnicity','Birth_City','Birth_State','Death_City','Death_State',
#     'Court_Type_1','Court_Name_1','Appointment_Title_1','Appointing_President_1','Party_of_Appointing_President_1','Reappointing_President_1','Party_of_Reappointing_President_1','ABA_Rating_1','Judiciary_Committee_Action_1','Senate_Vote_Type_1','Termination_1',
#     'Court_Type_2','Court_Name_2','Appointment_Title_2','Appointing_President_2','Party_of_Appointing_President_2','Reappointing_President_2','Party_of_Reappointing_President_2','ABA_Rating_2','Judiciary_Committee_Action_2','Senate_Vote_Type_2','Termination_2',
#     'Court_Type_3','Court_Name_3','Appointment_Title_3','Appointing_President_3','Party_of_Appointing_President_3','Reappointing_President_3','Party_of_Reappointing_President_3','ABA_Rating_3','Judiciary_Committee_Action_3','Senate_Vote_Type_3','Termination_3',
#     'Court_Type_4','Court_Name_4','Appointment_Title_4','Appointing_President_4','Party_of_Appointing_President_4','Reappointing_President_4','Party_of_Reappointing_President_4','ABA_Rating_4','Judiciary_Committee_Action_4','Senate_Vote_Type_4','Termination_4',
#     'Court_Type_5','Court_Name_5','Appointment_Title_5','Appointing_President_5','Party_of_Appointing_President_5','Reappointing_President_5','Party_of_Reappointing_President_5','ABA_Rating_5','Judiciary_Committee_Action_5','Senate_Vote_Type_5','Termination_5',
#     'Court_Type_6','Court_Name_6','Appointment_Title_6','Appointing_President_6','Party_of_Appointing_President_6','Reappointing_President_6','Party_of_Reappointing_President_6','ABA_Rating_6','Judiciary_Committee_Action_6','Senate_Vote_Type_6','Termination_6',
#     'School_1','Degree_1','School_2','Degree_2','School_3','Degree_3','School_4','Degree_4','School_5','Degree_5'
# ]
# df[forceCat] = df[forceCat].astype('category')
# df.memory_usage().sum() / original_size * 100

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3694 entries, 0 to 3693
# Data columns (total 204 columns):
# nid                                        int64
# jid                                        int64
# Last_Name                                  object
# First_Name                                 object
# Middle_Name                                object
# Suffix                                     object
# Birth_Month                                int32
# Birth_Day                                  int32
# Birth_Year                                 int32
# Birth_City                                 object
# Birth_State                                object
# Death_Month                                int32
# Death_Day                                  int32
# Death_Year                                 int32
# Death_City                                 object
# Death_State                                object
# Gender                                     object
# Race_or_Ethnicity                          object
# Court_Type_1                               object
# Court_Name_1                               object
# Appointment_Title_1                        object
# Appointing_President_1                     object
# Party_of_Appointing_President_1            object
# Reappointing_President_1                   object
# Party_of_Reappointing_President_1          object
# ABA_Rating_1                               object
# Seat_ID_1                                  object
# Statute_Authorizing_New_Seat_1             object
# Recess_Appointment_Date_1                  datetime64[ns]
# Nomination_Date_1                          datetime64[ns]
# Committee_Referral_Date_1                  datetime64[ns]
# Hearing_Date_1                             datetime64[ns]
# Judiciary_Committee_Action_1               object
# Committee_Action_Date_1                    datetime64[ns]
# Senate_Vote_Type_1                         object
# Ayes_n_Nays_1                              object
# Confirmation_Date_1                        datetime64[ns]
# Commission_Date_1                          datetime64[ns]
# Service_as_Chief_Judge_Begin_1             datetime64[ns]
# Service_as_Chief_Judge_End_1               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_1         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_1           datetime64[ns]
# Senior_Status_Date_1                       datetime64[ns]
# Termination_1                              object
# Termination_Date_1                         datetime64[ns]
# Court_Type_2                               object
# Court_Name_2                               object
# Appointment_Title_2                        object
# Appointing_President_2                     object
# Party_of_Appointing_President_2            object
# Reappointing_President_2                   float64
# Party_of_Reappointing_President_2          float64
# ABA_Rating_2                               object
# Seat_ID_2                                  object
# Statute_Authorizing_New_Seat_2             object
# Recess_Appointment_Date_2                  datetime64[ns]
# Nomination_Date_2                          datetime64[ns]
# Committee_Referral_Date_2                  datetime64[ns]
# Hearing_Date_2                             datetime64[ns]
# Judiciary_Committee_Action_2               object
# Committee_Action_Date_2                    datetime64[ns]
# Senate_Vote_Type_2                         object
# Ayes_n_Nays_2                              object
# Confirmation_Date_2                        datetime64[ns]
# Commission_Date_2                          datetime64[ns]
# Service_as_Chief_Judge_Begin_2             datetime64[ns]
# Service_as_Chief_Judge_End_2               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_2         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_2           datetime64[ns]
# Senior_Status_Date_2                       datetime64[ns]
# Termination_2                              object
# Termination_Date_2                         datetime64[ns]
# Court_Type_3                               object
# Court_Name_3                               object
# Appointment_Title_3                        object
# Appointing_President_3                     object
# Party_of_Appointing_President_3            object
# Reappointing_President_3                   float64
# Party_of_Reappointing_President_3          float64
# ABA_Rating_3                               object
# Seat_ID_3                                  object
# Statute_Authorizing_New_Seat_3             object
# Recess_Appointment_Date_3                  datetime64[ns]
# Nomination_Date_3                          datetime64[ns]
# Committee_Referral_Date_3                  datetime64[ns]
# Hearing_Date_3                             datetime64[ns]
# Judiciary_Committee_Action_3               object
# Committee_Action_Date_3                    datetime64[ns]
# Senate_Vote_Type_3                         object
# Ayes_n_Nays_3                              object
# Confirmation_Date_3                        datetime64[ns]
# Commission_Date_3                          datetime64[ns]
# Service_as_Chief_Judge_Begin_3             datetime64[ns]
# Service_as_Chief_Judge_End_3               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_3         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_3           datetime64[ns]
# Senior_Status_Date_3                       datetime64[ns]
# Termination_3                              object
# Termination_Date_3                         datetime64[ns]
# Court_Type_4                               object
# Court_Name_4                               object
# Appointment_Title_4                        object
# Appointing_President_4                     object
# Party_of_Appointing_President_4            object
# Reappointing_President_4                   float64
# Party_of_Reappointing_President_4          float64
# ABA_Rating_4                               float64
# Seat_ID_4                                  object
# Statute_Authorizing_New_Seat_4             object
# Recess_Appointment_Date_4                  datetime64[ns]
# Nomination_Date_4                          datetime64[ns]
# Committee_Referral_Date_4                  datetime64[ns]
# Hearing_Date_4                             datetime64[ns]
# Judiciary_Committee_Action_4               object
# Committee_Action_Date_4                    datetime64[ns]
# Senate_Vote_Type_4                         object
# Ayes_n_Nays_4                              object
# Confirmation_Date_4                        datetime64[ns]
# Commission_Date_4                          datetime64[ns]
# Service_as_Chief_Judge_Begin_4             datetime64[ns]
# Service_as_Chief_Judge_End_4               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_4         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_4           datetime64[ns]
# Senior_Status_Date_4                       datetime64[ns]
# Termination_4                              object
# Termination_Date_4                         datetime64[ns]
# Court_Type_5                               object
# Court_Name_5                               object
# Appointment_Title_5                        object
# Appointing_President_5                     object
# Party_of_Appointing_President_5            object
# Reappointing_President_5                   float64
# Party_of_Reappointing_President_5          float64
# ABA_Rating_5                               float64
# Seat_ID_5                                  object
# Statute_Authorizing_New_Seat_5             object
# Recess_Appointment_Date_5                  datetime64[ns]
# Nomination_Date_5                          datetime64[ns]
# Committee_Referral_Date_5                  datetime64[ns]
# Hearing_Date_5                             datetime64[ns]
# Judiciary_Committee_Action_5               object
# Committee_Action_Date_5                    datetime64[ns]
# Senate_Vote_Type_5                         float64
# Ayes_n_Nays_5                              object
# Confirmation_Date_5                        datetime64[ns]
# Commission_Date_5                          datetime64[ns]
# Service_as_Chief_Judge_Begin_5             datetime64[ns]
# Service_as_Chief_Judge_End_5               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_5         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_5           datetime64[ns]
# Senior_Status_Date_5                       datetime64[ns]
# Termination_5                              object
# Termination_Date_5                         datetime64[ns]
# Court_Type_6                               object
# Court_Name_6                               object
# Appointment_Title_6                        object
# Appointing_President_6                     object
# Party_of_Appointing_President_6            object
# Reappointing_President_6                   float64
# Party_of_Reappointing_President_6          float64
# ABA_Rating_6                               float64
# Seat_ID_6                                  object
# Statute_Authorizing_New_Seat_6             object
# Recess_Appointment_Date_6                  datetime64[ns]
# Nomination_Date_6                          datetime64[ns]
# Committee_Referral_Date_6                  datetime64[ns]
# Hearing_Date_6                             datetime64[ns]
# Judiciary_Committee_Action_6               object
# Committee_Action_Date_6                    datetime64[ns]
# Senate_Vote_Type_6                         float64
# Ayes_n_Nays_6                              object
# Confirmation_Date_6                        datetime64[ns]
# Commission_Date_6                          datetime64[ns]
# Service_as_Chief_Judge_Begin_6             datetime64[ns]
# Service_as_Chief_Judge_End_6               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_6         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_6           datetime64[ns]
# Senior_Status_Date_6                       datetime64[ns]
# Termination_6                              object
# Termination_Date_6                         datetime64[ns]
# Other_Federal_Judicial_Service_1           object
# Other_Federal_Judicial_Service_2           object
# Other_Federal_Judicial_Service_3           object
# Other_Federal_Judicial_Service_4           object
# School_1                                   object
# Degree_1                                   object
# Degree_Year_1                              datetime64[ns]
# School_2                                   object
# Degree_2                                   object
# Degree_Year_2                              datetime64[ns]
# School_3                                   object
# Degree_3                                   object
# Degree_Year_3                              datetime64[ns]
# School_4                                   object
# Degree_4                                   object
# Degree_Year_4                              datetime64[ns]
# School_5                                   object
# Degree_5                                   object
# Degree_Year_5                              datetime64[ns]
# Professional_Career                        object
# Other_Nominations_n_Recess_Appointments    object
# Birth_Date                                 datetime64[ns]
# Death_Date                                 datetime64[ns]
# Full_Name                                  object
# dtypes: datetime64[ns](85), float64(15), int32(6), int64(2), object(96)
# memory usage: 4.3+ MB

# %% [markdown]
# # Join Key Tables

# %% [markdown]
# ### Additional Info on Presidents

# %%
columns = ['Pres_Num','Pres_Name','Pres_State_Abbrev']
pres_df = pd.read_csv("sources/key_presidents.csv", usecols=columns)
df = df.merge(pres_df, left_on='Appointing_President_1', right_on='Pres_Name')
df = df.rename({'Pres_Num':'Appointing_President_Num_1', 'Pres_State_Abbrev':'Appointing_President_State_1'}, axis=1)
del df['Pres_Name']
df.head()
# Out:
#        nid   jid  Last_Name First_Name Middle_Name Suffix  Birth_Month  \
# 0  1393126  3258  Scarburgh     George      Parker                   2
# 1  1393041  3241  Gilchrist       John       James                   2
# 2  1393006  3234  Blackford      Isaac      Newton                  11
# 3  1378771   361   Campbell       John   Archibald                   6
# 4  1390926  2818     Dunlop      James                               3
#
#    Birth_Day  Birth_Year       Birth_City  ... School_5  Degree_5  \
# 0         11        1807  Accomack County  ...      NaN       NaN
# 1         16        1809          Medford  ...      NaN       NaN
# 2          6        1786      Bound Brook  ...      NaN       NaN
# 3         24        1811       Washington  ...      NaN       NaN
# 4         28        1793       Georgetown  ...      NaN       NaN
#
#    Degree_Year_5                                Professional_Career  \
# 0            NaT  Private practice, Accomack County, Virginia, 1...
# 1            NaT  Private practice, Charlestown, New Hampshire, ...
# 2            NaT  Private practice, Indiana Territory, 1812-1813...
# 3            NaT  Private practice, Washington, Georgia, 1829; P...
# 4            NaT  Private practice, Georgetown, D.C., 1863-1872;...
#
#   Other_Nominations_n_Recess_Appointments Birth_Date Death_Date  \
# 0                                     NaN 1807-02-11 1879-12-21
# 1                                     NaN 1809-02-16 1858-04-29
# 2                                     NaN 1786-11-06 1859-12-31
# 3                                     NaN 1811-06-24 1889-03-12
# 4                                     NaN 1793-03-28 1872-05-06
#
#                  Full_Name Appointing_President_Num_1  \
# 0  George Parker Scarburgh                         14
# 1     John James Gilchrist                         14
# 2   Isaac Newton Blackford                         14
# 3  John Archibald Campbell                         14
# 4             James Dunlop                         14
#
#   Appointing_President_State_1
# 0                           NH
# 1                           NH
# 2                           NH
# 3                           NH
# 4                           NH
#
# [5 rows x 206 columns]

# %% [markdown]
# ### Additional Info on Courts
# * This will delete rows of very outdated courts/panels; to maintain, switch "how" field to "outer"

# %%
columns = ['Court_Circuit','Court_Name_Long','Court_Abbrev_Bluebook','Court_Abbrev_Website','State_Abbrev']
pres_df = pd.read_csv("sources/key_courts.csv", usecols=columns)
df = df.merge(pres_df, how='inner', left_on='Court_Name_1', right_on='Court_Name_Long')
df = df.rename({'Court_Circuit':'Court_Circuit_1','Court_Abbrev_Bluebook':'Court_Abbrev_Bluebook_1','Court_Abbrev_Website':'Court_Abbrev_Website_1','State_Abbrev':'Court_State_1'}, axis=1)
del df['Court_Name_Long']
df.head()
# Out:
#        nid   jid  Last_Name First_Name Middle_Name Suffix  Birth_Month  \
# 0  1393126  3258  Scarburgh     George      Parker                   2
# 1  1393041  3241  Gilchrist       John       James                   2
# 2  1393006  3234  Blackford      Isaac      Newton                  11
# 3  1393146  3262     Loring     Edward      Greely                   1
# 4  1393186  3270     Hughes      James                              11
#
#    Birth_Day  Birth_Year       Birth_City  ...  \
# 0         11        1807  Accomack County  ...
# 1         16        1809          Medford  ...
# 2          6        1786      Bound Brook  ...
# 3         28        1802           Boston  ...
# 4         24        1823      Bladensburg  ...
#
#   Other_Nominations_n_Recess_Appointments  Birth_Date  Death_Date  \
# 0                                     NaN  1807-02-11  1879-12-21
# 1                                     NaN  1809-02-16  1858-04-29
# 2                                     NaN  1786-11-06  1859-12-31
# 3                                     NaN  1802-01-28  1890-06-19
# 4                                     NaN  1823-11-24  1873-10-21
#
#                  Full_Name Appointing_President_Num_1  \
# 0  George Parker Scarburgh                         14
# 1     John James Gilchrist                         14
# 2   Isaac Newton Blackford                         14
# 3     Edward Greely Loring                         15
# 4             James Hughes                         15
#
#   Appointing_President_State_1 Court_Circuit_1 Court_Abbrev_Bluebook_1  \
# 0                           NH             NaN                     NaN
# 1                           NH             NaN                     NaN
# 2                           NH             NaN                     NaN
# 3                           PA             NaN                     NaN
# 4                           PA             NaN                     NaN
#
#   Court_Abbrev_Website_1 Court_State_1
# 0                    NaN           NaN
# 1                    NaN           NaN
# 2                    NaN           NaN
# 3                    NaN           NaN
# 4                    NaN           NaN
#
# [5 rows x 210 columns]

# %% [markdown]
# ### Court "Emergencies"

# %%
columns = ['Court_Code','First_Name','Last_Name','Weighted_Filings_Per_Seat','Adjusted_Filings_Per_Panel','Vacancy_Reason']
emrg_df = pd.read_csv("sources/judicial_emergencies.csv", usecols=columns)
df = df.merge(emrg_df, how='left', left_on=['First_Name','Last_Name','Court_Abbrev_Website_1'], right_on=['First_Name','Last_Name','Court_Code'])
df = df.rename({'Weighted_Filings_Per_Seat':'Filings_Per_Seat_Weighted','Adjusted_Filings_Per_Panel':'Filings_Per_Panel_Adjusted'}, axis=1)
# del df['Court_Code']
df.head()
# Out:
#        nid   jid  Last_Name First_Name Middle_Name Suffix  Birth_Month  \
# 0  1393126  3258  Scarburgh     George      Parker                   2
# 1  1393041  3241  Gilchrist       John       James                   2
# 2  1393006  3234  Blackford      Isaac      Newton                  11
# 3  1393146  3262     Loring     Edward      Greely                   1
# 4  1393186  3270     Hughes      James                              11
#
#    Birth_Day  Birth_Year       Birth_City  ... Appointing_President_Num_1  \
# 0         11        1807  Accomack County  ...                         14
# 1         16        1809          Medford  ...                         14
# 2          6        1786      Bound Brook  ...                         14
# 3         28        1802           Boston  ...                         15
# 4         24        1823      Bladensburg  ...                         15
#
#    Appointing_President_State_1  Court_Circuit_1  Court_Abbrev_Bluebook_1  \
# 0                            NH              NaN                      NaN
# 1                            NH              NaN                      NaN
# 2                            NH              NaN                      NaN
# 3                            PA              NaN                      NaN
# 4                            PA              NaN                      NaN
#
#   Court_Abbrev_Website_1 Court_State_1 Court_Code Vacancy_Reason  \
# 0                    NaN           NaN        NaN            NaN
# 1                    NaN           NaN        NaN            NaN
# 2                    NaN           NaN        NaN            NaN
# 3                    NaN           NaN        NaN            NaN
# 4                    NaN           NaN        NaN            NaN
#
#   Filings_Per_Seat_Weighted Filings_Per_Panel_Adjusted
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
# [5 rows x 214 columns]

# %%
df['Vacancy_Date'] = df[['Termination_Date_1','Senior_Status_Date_1']].max(axis=1)
SCRAPE_TIME = np.datetime64(datetime.datetime.now())
df['Vacancy_Duration_ATSCRAPE'] = SCRAPE_TIME - df.Vacancy_Date

# %%
df.Vacancy_Duration_ATSCRAPE.head()  #.astype(str).str.extract(r'(\d*)\s').head()
# Out:
# 0   57785 days 01:27:23.045008
# 1   58872 days 01:27:23.045008
# 2   58261 days 01:27:23.045008
# 3   51703 days 01:27:23.045008
# 4   56464 days 01:27:23.045008
# Name: Vacancy_Duration_ATSCRAPE, dtype: timedelta64[ns]

# %%
df.memory_usage().sum() / original_size * 100
# Out:
# 117.70242360643675

# %%
# df[['Appointing_President_State_1','Court_Circuit_1','Court_Abbrev_Bluebook_1','Court_Abbrev_Website_1','Court_State_1']] = df[['Appointing_President_State_1','Court_Circuit_1','Court_Abbrev_Bluebook_1','Court_Abbrev_Website_1','Court_State_1']].astype('category')
# df.memory_usage().sum() / original_size * 100

# %% [markdown]
# ### Set Colors

# %%
# colorsP = {'Democratic': 'lightskyblue', 
#           'Federalist': 'slategrey', 
#           'Jeffersonian Republican': 'seagreen', 
#           'Republican': 'crimson', 
#           'Whig': 'gold'}
# df['Party_Color_1'] = df['Party_of_Appointing_President_1'].map(colorsP)
# colorsC = {'Supreme Court': 'darkgoldenrod', 
#           'U.S. Court of Appeals': 'gold', 
#           'U.S. District Court': 'palegoldenrod', 
#           'Other': 'navajowhite'}
# df['Court_Color_1'] = df['Court_Type_1'].map(colorsC)

# %% [markdown]
# ### Make Useful Repeating Seat Code (not tied to individuals)

# %%
df['Seat_ID_SeatNum_1'] = df.Seat_ID_1.str.extract(r'.*(\d\d)\d\d').dropna()
df['Seat_ID_Code_1'] = df.Court_Abbrev_Website_1.str.replace(r' ',r'') + '-'
df['Seat_Code_1'] = df.Seat_ID_Code_1 + df.Seat_ID_SeatNum_1
df = df.drop(['Seat_ID_Code_1','Seat_ID_SeatNum_1'], axis=1)
# df.Seat_Code_1 = df.Seat_Code_1.astype('category')
df.Seat_Code_1.value_counts().head(10)
# Out:
# SC-04         19
# SC-01         18
# 03-NJ-02      17
# 03-PA-W-01    16
# 01-RI-01      14
# SC-05         13
# SC-03         13
# 02-VT-01      13
# SC-07         12
# 09-CCA-03     12
# Name: Seat_Code_1, dtype: int64

# %% [markdown]
# ### Check Additions

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3465 entries, 0 to 3464
# Data columns (total 217 columns):
# nid                                        int64
# jid                                        int64
# Last_Name                                  object
# First_Name                                 object
# Middle_Name                                object
# Suffix                                     object
# Birth_Month                                int32
# Birth_Day                                  int32
# Birth_Year                                 int32
# Birth_City                                 object
# Birth_State                                object
# Death_Month                                int32
# Death_Day                                  int32
# Death_Year                                 int32
# Death_City                                 object
# Death_State                                object
# Gender                                     object
# Race_or_Ethnicity                          object
# Court_Type_1                               object
# Court_Name_1                               object
# Appointment_Title_1                        object
# Appointing_President_1                     object
# Party_of_Appointing_President_1            object
# Reappointing_President_1                   object
# Party_of_Reappointing_President_1          object
# ABA_Rating_1                               object
# Seat_ID_1                                  object
# Statute_Authorizing_New_Seat_1             object
# Recess_Appointment_Date_1                  datetime64[ns]
# Nomination_Date_1                          datetime64[ns]
# Committee_Referral_Date_1                  datetime64[ns]
# Hearing_Date_1                             datetime64[ns]
# Judiciary_Committee_Action_1               object
# Committee_Action_Date_1                    datetime64[ns]
# Senate_Vote_Type_1                         object
# Ayes_n_Nays_1                              object
# Confirmation_Date_1                        datetime64[ns]
# Commission_Date_1                          datetime64[ns]
# Service_as_Chief_Judge_Begin_1             datetime64[ns]
# Service_as_Chief_Judge_End_1               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_1         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_1           datetime64[ns]
# Senior_Status_Date_1                       datetime64[ns]
# Termination_1                              object
# Termination_Date_1                         datetime64[ns]
# Court_Type_2                               object
# Court_Name_2                               object
# Appointment_Title_2                        object
# Appointing_President_2                     object
# Party_of_Appointing_President_2            object
# Reappointing_President_2                   float64
# Party_of_Reappointing_President_2          float64
# ABA_Rating_2                               object
# Seat_ID_2                                  object
# Statute_Authorizing_New_Seat_2             object
# Recess_Appointment_Date_2                  datetime64[ns]
# Nomination_Date_2                          datetime64[ns]
# Committee_Referral_Date_2                  datetime64[ns]
# Hearing_Date_2                             datetime64[ns]
# Judiciary_Committee_Action_2               object
# Committee_Action_Date_2                    datetime64[ns]
# Senate_Vote_Type_2                         object
# Ayes_n_Nays_2                              object
# Confirmation_Date_2                        datetime64[ns]
# Commission_Date_2                          datetime64[ns]
# Service_as_Chief_Judge_Begin_2             datetime64[ns]
# Service_as_Chief_Judge_End_2               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_2         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_2           datetime64[ns]
# Senior_Status_Date_2                       datetime64[ns]
# Termination_2                              object
# Termination_Date_2                         datetime64[ns]
# Court_Type_3                               object
# Court_Name_3                               object
# Appointment_Title_3                        object
# Appointing_President_3                     object
# Party_of_Appointing_President_3            object
# Reappointing_President_3                   float64
# Party_of_Reappointing_President_3          float64
# ABA_Rating_3                               object
# Seat_ID_3                                  object
# Statute_Authorizing_New_Seat_3             object
# Recess_Appointment_Date_3                  datetime64[ns]
# Nomination_Date_3                          datetime64[ns]
# Committee_Referral_Date_3                  datetime64[ns]
# Hearing_Date_3                             datetime64[ns]
# Judiciary_Committee_Action_3               object
# Committee_Action_Date_3                    datetime64[ns]
# Senate_Vote_Type_3                         object
# Ayes_n_Nays_3                              object
# Confirmation_Date_3                        datetime64[ns]
# Commission_Date_3                          datetime64[ns]
# Service_as_Chief_Judge_Begin_3             datetime64[ns]
# Service_as_Chief_Judge_End_3               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_3         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_3           datetime64[ns]
# Senior_Status_Date_3                       datetime64[ns]
# Termination_3                              object
# Termination_Date_3                         datetime64[ns]
# Court_Type_4                               object
# Court_Name_4                               object
# Appointment_Title_4                        object
# Appointing_President_4                     object
# Party_of_Appointing_President_4            object
# Reappointing_President_4                   float64
# Party_of_Reappointing_President_4          float64
# ABA_Rating_4                               float64
# Seat_ID_4                                  object
# Statute_Authorizing_New_Seat_4             object
# Recess_Appointment_Date_4                  datetime64[ns]
# Nomination_Date_4                          datetime64[ns]
# Committee_Referral_Date_4                  datetime64[ns]
# Hearing_Date_4                             datetime64[ns]
# Judiciary_Committee_Action_4               object
# Committee_Action_Date_4                    datetime64[ns]
# Senate_Vote_Type_4                         object
# Ayes_n_Nays_4                              object
# Confirmation_Date_4                        datetime64[ns]
# Commission_Date_4                          datetime64[ns]
# Service_as_Chief_Judge_Begin_4             datetime64[ns]
# Service_as_Chief_Judge_End_4               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_4         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_4           datetime64[ns]
# Senior_Status_Date_4                       datetime64[ns]
# Termination_4                              object
# Termination_Date_4                         datetime64[ns]
# Court_Type_5                               object
# Court_Name_5                               object
# Appointment_Title_5                        object
# Appointing_President_5                     object
# Party_of_Appointing_President_5            object
# Reappointing_President_5                   float64
# Party_of_Reappointing_President_5          float64
# ABA_Rating_5                               float64
# Seat_ID_5                                  object
# Statute_Authorizing_New_Seat_5             object
# Recess_Appointment_Date_5                  datetime64[ns]
# Nomination_Date_5                          datetime64[ns]
# Committee_Referral_Date_5                  datetime64[ns]
# Hearing_Date_5                             datetime64[ns]
# Judiciary_Committee_Action_5               object
# Committee_Action_Date_5                    datetime64[ns]
# Senate_Vote_Type_5                         float64
# Ayes_n_Nays_5                              object
# Confirmation_Date_5                        datetime64[ns]
# Commission_Date_5                          datetime64[ns]
# Service_as_Chief_Judge_Begin_5             datetime64[ns]
# Service_as_Chief_Judge_End_5               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_5         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_5           datetime64[ns]
# Senior_Status_Date_5                       datetime64[ns]
# Termination_5                              object
# Termination_Date_5                         datetime64[ns]
# Court_Type_6                               object
# Court_Name_6                               object
# Appointment_Title_6                        object
# Appointing_President_6                     object
# Party_of_Appointing_President_6            object
# Reappointing_President_6                   float64
# Party_of_Reappointing_President_6          float64
# ABA_Rating_6                               float64
# Seat_ID_6                                  object
# Statute_Authorizing_New_Seat_6             object
# Recess_Appointment_Date_6                  datetime64[ns]
# Nomination_Date_6                          datetime64[ns]
# Committee_Referral_Date_6                  datetime64[ns]
# Hearing_Date_6                             datetime64[ns]
# Judiciary_Committee_Action_6               object
# Committee_Action_Date_6                    datetime64[ns]
# Senate_Vote_Type_6                         float64
# Ayes_n_Nays_6                              object
# Confirmation_Date_6                        datetime64[ns]
# Commission_Date_6                          datetime64[ns]
# Service_as_Chief_Judge_Begin_6             datetime64[ns]
# Service_as_Chief_Judge_End_6               datetime64[ns]
# 2nd_Service_as_Chief_Judge_Begin_6         datetime64[ns]
# 2nd_Service_as_Chief_Judge_End_6           datetime64[ns]
# Senior_Status_Date_6                       datetime64[ns]
# Termination_6                              object
# Termination_Date_6                         datetime64[ns]
# Other_Federal_Judicial_Service_1           object
# Other_Federal_Judicial_Service_2           object
# Other_Federal_Judicial_Service_3           object
# Other_Federal_Judicial_Service_4           object
# School_1                                   object
# Degree_1                                   object
# Degree_Year_1                              datetime64[ns]
# School_2                                   object
# Degree_2                                   object
# Degree_Year_2                              datetime64[ns]
# School_3                                   object
# Degree_3                                   object
# Degree_Year_3                              datetime64[ns]
# School_4                                   object
# Degree_4                                   object
# Degree_Year_4                              datetime64[ns]
# School_5                                   object
# Degree_5                                   object
# Degree_Year_5                              datetime64[ns]
# Professional_Career                        object
# Other_Nominations_n_Recess_Appointments    object
# Birth_Date                                 datetime64[ns]
# Death_Date                                 datetime64[ns]
# Full_Name                                  object
# Appointing_President_Num_1                 int64
# Appointing_President_State_1               object
# Court_Circuit_1                            object
# Court_Abbrev_Bluebook_1                    object
# Court_Abbrev_Website_1                     object
# Court_State_1                              object
# Court_Code                                 object
# Vacancy_Reason                             object
# Filings_Per_Seat_Weighted                  float64
# Filings_Per_Panel_Adjusted                 float64
# Vacancy_Date                               datetime64[ns]
# Vacancy_Duration_ATSCRAPE                  timedelta64[ns]
# Seat_Code_1                                object
# dtypes: datetime64[ns](86), float64(17), int32(6), int64(3), object(104), timedelta64[ns](1)
# memory usage: 4.3+ MB

# %% [markdown]
# # Basic Research

# %% [markdown]
# ### Most Appointments

# %%
df.Appointing_President_1.value_counts()
# Out:
# William J. Clinton       357
# Ronald Reagan            338
# Barack Obama             324
# George W. Bush           314
# Jimmy Carter             239
# Richard M. Nixon         200
# George H.W. Bush         178
# Franklin D. Roosevelt    169
# Lyndon B. Johnson        148
# Dwight D. Eisenhower     148
# Donald J. Trump          122
# Harry S Truman           121
# John F. Kennedy           99
# Calvin Coolidge           71
# Grover Cleveland          62
# Theodore Roosevelt        58
# Woodrow Wilson            57
# Herbert Hoover            54
# Gerald Ford               49
# William H. Taft           45
# Warren G. Harding         43
# Ulysses Grant             30
# Benjamin Harrison         29
# William McKinley          24
# Abraham Lincoln           22
# George Washington         21
# Chester A. Arthur         18
# Franklin Pierce           15
# James Monroe              13
# Rutherford B. Hayes       12
# Andrew Jackson            11
# James Buchanan             9
# Martin Van Buren           9
# John Quincy Adams          9
# Andrew Johnson             8
# Thomas Jefferson           7
# James Madison              6
# John Adams                 6
# James K. Polk              5
# John Tyler                 5
# James A. Garfield          4
# Millard Fillmore           4
# Zachary Taylor             2
# Name: Appointing_President_1, dtype: int64

# %%
df.groupby(by='Appointing_President_Num_1').Appointing_President_1.value_counts().plot(kind='bar',figsize=(18, 8))
plt.tight_layout()

# %%
df.groupby(by='Appointing_President_Num_1').Court_Type_1.value_counts().plot(kind='bar',figsize=(18, 8))
plt.tight_layout()

# %% [markdown]
# ### Qualifications
# - ABA Rating
# - Committee Recommendations
# - Termination Types

# %%
df.ABA_Rating_1.value_counts()
# Out:
# Well Qualified                    1270
# Qualified                          891
# Not Qualified                       16
# Exceptionally Well Qualified        15
# Not Qualified By Reason of Age       2
# Name: ABA_Rating_1, dtype: int64

# %%
df[df.ABA_Rating_1.str.contains("Not", na=False)]['Appointing_President_1'].value_counts()
# Out:
# Lyndon B. Johnson     5
# George W. Bush        4
# Donald J. Trump       4
# Jimmy Carter          2
# William J. Clinton    2
# John F. Kennedy       1
# Name: Appointing_President_1, dtype: int64

# %%
df[df.ABA_Rating_1.str.contains("Not", na=False)][['Full_Name','ABA_Rating_1','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#                             Full_Name                    ABA_Rating_1  \
# 1070                              NaN                   Not Qualified
# 2781                              NaN                   Not Qualified
# 1443                              NaN                   Not Qualified
# 1068                              NaN                   Not Qualified
# 3009  Gregory Frederick Van Tatenhove                   Not Qualified
# 1620                 Dora L. Irizarry                   Not Qualified
# 406                  Roger T. Benitez                   Not Qualified
# 3008                 David L. Bunning                   Not Qualified
# 354                     David A. Katz                   Not Qualified
# 210           Alexander Williams, Jr.                   Not Qualified
# 1721                     U. W. Clemon                   Not Qualified
# 891             Donald Eugene O'Brien                   Not Qualified
# 1090           Edward Matthew McEntee                   Not Qualified
# 2843            Charles Andrew Muecke                   Not Qualified
# 2636             Eugene Andrew Gordon                   Not Qualified
# 3104              Sidney Lee Christie  Not Qualified By Reason of Age
# 2220            Sarah Tilghman Hughes  Not Qualified By Reason of Age
# 2079                 David Rabinovitz                   Not Qualified
#
#      Appointing_President_1 Confirmation_Date_1
# 1070        Donald J. Trump          2018-12-11
# 2781        Donald J. Trump          2018-08-28
# 1443        Donald J. Trump          2018-08-01
# 1068        Donald J. Trump          2017-12-12
# 3009         George W. Bush          2005-12-21
# 1620         George W. Bush          2004-06-24
# 406          George W. Bush          2004-06-17
# 3008         George W. Bush          2002-02-14
# 354      William J. Clinton          1994-10-07
# 210      William J. Clinton          1994-08-17
# 1721           Jimmy Carter          1980-06-26
# 891            Jimmy Carter          1978-10-04
# 1090      Lyndon B. Johnson          1965-08-31
# 2843      Lyndon B. Johnson          1964-09-29
# 2636      Lyndon B. Johnson          1964-05-27
# 3104      Lyndon B. Johnson          1964-04-30
# 2220        John F. Kennedy          1962-03-16
# 2079      Lyndon B. Johnson                 NaT

# %%
df[df.ABA_Rating_2.str.contains("Not", na=False)][['Full_Name','ABA_Rating_2','Appointing_President_2','Confirmation_Date_2']].sort_values(by='Confirmation_Date_2', ascending=False)
# Out:
#                   Full_Name                    ABA_Rating_2  \
# 1272   David Frank Hamilton                   Not Qualified
# 891   Donald Eugene O'Brien                   Not Qualified
# 3104    Sidney Lee Christie  Not Qualified By Reason of Age
#
#      Appointing_President_2 Confirmation_Date_2
# 1272     William J. Clinton          1994-10-07
# 891            Jimmy Carter          1978-10-04
# 3104      Lyndon B. Johnson          1964-04-30

# %%
df.Judiciary_Committee_Action_1.value_counts()
# Out:
# Reported (favorably)                     3255
# Reported (no recommendation recorded)      70
# Not Referred to Committee                  61
# No Committee before December 10, 1816      40
# Not Reported                               12
# Reported (unknown)                          9
# Reported (unfavorably)                      8
# Reported (without recommendation)           6
# Name: Judiciary_Committee_Action_1, dtype: int64

# %%
df[~df.Judiciary_Committee_Action_1.str.contains("\(favorably", na=False)][['Full_Name','Judiciary_Committee_Action_1','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False).dropna().head(60)
# Out:
#                              Full_Name           Judiciary_Committee_Action_1  \
# 2533               J[ames] Leon Holmes      Reported (without recommendation)
# 104                    Clarence Thomas      Reported (without recommendation)
# 1263             Daniel Anthony Manion      Reported (without recommendation)
# 2808                John Joseph Hickey  Reported (no recommendation recorded)
# 1379             Collins Jacques Seitz  Reported (no recommendation recorded)
# 1557      Frederick Jacob Reagan Heebe  Reported (no recommendation recorded)
# 2514               Russell Evans Smith  Reported (no recommendation recorded)
# 1345       George Clifton Edwards, Jr.  Reported (no recommendation recorded)
# 706                    Edward Dumbauld                           Not Reported
# 1073             Albert Alphonso Ridge  Reported (no recommendation recorded)
# 2617                Frank Wiley Wilson  Reported (no recommendation recorded)
# 2400                 Homer Truett Bone              Not Referred to Committee
# 2713                 Richard M. Duncan              Not Referred to Committee
# 281                 Rubey Mosley Hulen              Not Referred to Committee
# 53                James Francis Byrnes              Not Referred to Committee
# 3117                 John Elvis Miller              Not Referred to Committee
# 1656        Lewis Baxter Schwellenbach              Not Referred to Committee
# 1692         Thomas Alexander Murphree  Reported (no recommendation recorded)
# 2788            Joseph Raymond Jackson  Reported (no recommendation recorded)
# 973               Henry White Edgerton  Reported (no recommendation recorded)
# 2797               Sam Gilbert Bratton              Not Referred to Committee
# 3116                   Heartsill Ragon              Not Referred to Committee
# 464           Robert Johnston McMillan  Reported (no recommendation recorded)
# 18               Fenton Whitlock Booth                           Not Reported
# 100                  George Sutherland              Not Referred to Committee
# 1047             William Squire Kenyon              Not Referred to Committee
# 743                 John Andrew Peters                     Reported (unknown)
# 2991            George Franklin Morris                     Reported (unknown)
# 3220              Thomas Blake Kennedy                     Reported (unknown)
# 1188            Julius Marshuetz Mayer                     Reported (unknown)
# 3105          George Warwick McClintic                     Reported (unknown)
# 99                 William Howard Taft              Not Referred to Committee
# 1124               Edmund Waddill, Jr.                     Reported (unknown)
# 445                  John William Ross                     Reported (unknown)
# 1892                 William Eli Baker                     Reported (unknown)
# 2081                  Claude Zeth Luse                     Reported (unknown)
# 2088             Nathan Philemon Bryan                           Not Reported
# 1080          Charles Fletcher Johnson              Not Referred to Committee
# 1690            Henry De Lamar Clayton              Not Referred to Committee
# 94               Edward Douglass White              Not Referred to Committee
# 1107          Jeter Connelly Pritchard              Not Referred to Committee
# 1689                Thomas Goode Jones                           Not Reported
# 151                 George Shiras, Jr.      Reported (without recommendation)
# 60              Melville Weston Fuller      Reported (without recommendation)
# 59              Melville Weston Fuller      Reported (without recommendation)
# 61    Lucius Quintus Cincinnatus Lamar                 Reported (unfavorably)
# 62    Lucius Quintus Cincinnatus Lamar                 Reported (unfavorably)
# 91                    Stanley Matthews                 Reported (unfavorably)
# 196                 Thomas John Morris              Not Referred to Committee
# 1676                   Charles E. Dyer              Not Referred to Committee
# 916                Philip Bergen Swing              Not Referred to Committee
# 3121                     William Story              Not Referred to Committee
# 33                Charles Daniel Drake              Not Referred to Committee
# 2990                      Daniel Clark              Not Referred to Committee
# 73               Salmon Portland Chase              Not Referred to Committee
# 1428                   Mark W. Delahay  Reported (no recommendation recorded)
# 649                    Richard Busteed  Reported (no recommendation recorded)
# 2235          Thomas Jefferson Boynton  Reported (no recommendation recorded)
# 30                        Joseph Casey  Reported (no recommendation recorded)
# 2698              Solomon Lewis Withey  Reported (no recommendation recorded)
#
#      Appointing_President_1 Confirmation_Date_1
# 2533         George W. Bush          2004-07-06
# 104        George H.W. Bush          1991-10-15
# 1263          Ronald Reagan          1986-06-26
# 2808      Lyndon B. Johnson          1966-06-09
# 1379      Lyndon B. Johnson          1966-06-09
# 1557      Lyndon B. Johnson          1966-03-25
# 2514      Lyndon B. Johnson          1966-03-25
# 1345        John F. Kennedy          1963-12-16
# 706         John F. Kennedy          1961-08-02
# 1073        John F. Kennedy          1961-06-14
# 2617        John F. Kennedy          1961-06-14
# 2400  Franklin D. Roosevelt          1944-04-01
# 2713  Franklin D. Roosevelt          1943-07-08
# 281   Franklin D. Roosevelt          1943-07-08
# 53    Franklin D. Roosevelt          1941-06-12
# 3117  Franklin D. Roosevelt          1941-01-31
# 1656  Franklin D. Roosevelt          1940-05-06
# 1692  Franklin D. Roosevelt          1938-05-17
# 2788  Franklin D. Roosevelt          1937-12-09
# 973   Franklin D. Roosevelt          1937-12-09
# 2797  Franklin D. Roosevelt          1933-06-01
# 3116  Franklin D. Roosevelt          1933-05-12
# 464          Herbert Hoover          1932-01-12
# 18          Calvin Coolidge          1928-04-18
# 100       Warren G. Harding          1922-09-05
# 1047      Warren G. Harding          1922-01-31
# 743       Warren G. Harding          1921-11-14
# 2991      Warren G. Harding          1921-10-25
# 3220      Warren G. Harding          1921-10-25
# 1188      Warren G. Harding          1921-10-05
# 3105      Warren G. Harding          1921-07-25
# 99        Warren G. Harding          1921-06-30
# 1124      Warren G. Harding          1921-06-02
# 445       Warren G. Harding          1921-05-31
# 1892      Warren G. Harding          1921-05-03
# 2081      Warren G. Harding          1921-04-27
# 2088         Woodrow Wilson          1920-04-23
# 1080         Woodrow Wilson          1917-10-01
# 1690         Woodrow Wilson          1914-05-02
# 94          William H. Taft          1910-12-12
# 1107     Theodore Roosevelt          1904-04-27
# 1689     Theodore Roosevelt          1901-12-17
# 151       Benjamin Harrison          1892-07-26
# 60         Grover Cleveland          1888-07-20
# 59         Grover Cleveland          1888-07-20
# 61         Grover Cleveland          1888-01-16
# 62         Grover Cleveland          1888-01-16
# 91        James A. Garfield          1881-05-12
# 196     Rutherford B. Hayes          1879-07-01
# 1676          Ulysses Grant          1875-02-10
# 916           Ulysses Grant          1871-03-30
# 3121          Ulysses Grant          1871-03-03
# 33            Ulysses Grant          1870-12-12
# 2990         Andrew Johnson          1866-07-27
# 73          Abraham Lincoln          1864-12-06
# 1428        Abraham Lincoln          1864-03-15
# 649         Abraham Lincoln          1864-01-20
# 2235        Abraham Lincoln          1864-01-20
# 30          Abraham Lincoln          1863-03-13
# 2698        Abraham Lincoln          1863-03-11

# %%
df.Termination_1.value_counts()
# Out:
# Death                               1580
# Retirement                           290
# Resignation                          230
# Recess Appointment-Not Confirmed      16
# Impeachment & Conviction               8
# Name: Termination_1, dtype: int64

# %%
df[df.Termination_1.str.contains("Impeachment", na=False)][['Full_Name','Termination_1','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#                     Full_Name             Termination_1  \
# 1571  G. Thomas Porteous, Jr.  Impeachment & Conviction
# 2285     Alcee Lamar Hastings  Impeachment & Conviction
# 781        Harry E. Claiborne  Impeachment & Conviction
# 3087  Walter Louis Nixon, Jr.  Impeachment & Conviction
# 2229  Halsted Lockwood Ritter  Impeachment & Conviction
# 1385   Robert Wodrow Archbald  Impeachment & Conviction
# 439     West Hughes Humphreys  Impeachment & Conviction
# 2998           John Pickering  Impeachment & Conviction
#
#      Appointing_President_1 Confirmation_Date_1
# 1571     William J. Clinton          1994-10-07
# 2285           Jimmy Carter          1979-10-31
# 781            Jimmy Carter          1978-08-11
# 3087      Lyndon B. Johnson          1968-06-06
# 2229        Calvin Coolidge          1929-02-15
# 1385        William H. Taft          1911-01-31
# 439         Franklin Pierce          1853-03-26
# 2998      George Washington          1795-02-11

# %%
df[df.Termination_1.str.contains("Recess", na=False)][['Full_Name','Termination_1','Appointing_President_1','Recess_Appointment_Date_1']].sort_values(by='Recess_Appointment_Date_1', ascending=False)
# Out:
#                     Full_Name                     Termination_1  \
# 3218      Walter Meheula Heen  Recess Appointment-Not Confirmed
# 2079         David Rabinovitz  Recess Appointment-Not Confirmed
# 1734     Monroe Mark Friedman  Recess Appointment-Not Confirmed
# 851      Maurice Neil Andrews  Recess Appointment-Not Confirmed
# 2289       Carroll O. Switzer  Recess Appointment-Not Confirmed
# 942          Floyd H. Roberts  Recess Appointment-Not Confirmed
# 1794     George E. Q. Johnson  Recess Appointment-Not Confirmed
# 2394         Wallace McCamant  Recess Appointment-Not Confirmed
# 2245        John Moses Cheney  Recess Appointment-Not Confirmed
# 2360  Clinton Woodbury Howard  Recess Appointment-Not Confirmed
# 2845      Richard Elihu Sloan  Recess Appointment-Not Confirmed
# 2349    Hamilton Glover Ewart  Recess Appointment-Not Confirmed
# 1453   William Douglas McHugh  Recess Appointment-Not Confirmed
# 1454   William Douglas McHugh  Recess Appointment-Not Confirmed
# 821          Joel C. C. Winch  Recess Appointment-Not Confirmed
# 116             John Rutledge  Recess Appointment-Not Confirmed
#
#      Appointing_President_1 Recess_Appointment_Date_1
# 3218           Jimmy Carter                1981-01-01
# 2079      Lyndon B. Johnson                1964-01-07
# 1734         Harry S Truman                1952-07-17
# 851          Harry S Truman                1949-10-21
# 2289         Harry S Truman                1949-10-21
# 942   Franklin D. Roosevelt                1938-07-06
# 1794         Herbert Hoover                1932-08-03
# 2394        Calvin Coolidge                1925-05-25
# 2245        William H. Taft                1912-08-26
# 2360        William H. Taft                1912-08-26
# 2845        William H. Taft                1912-08-26
# 2349       William McKinley                1899-04-13
# 1453       Grover Cleveland                1896-11-20
# 1454       Grover Cleveland                1896-11-20
# 821           Ulysses Grant                1870-10-11
# 116       George Washington                1795-07-01

# %% [markdown]
# ### Declined & Rejected Appointments

# %%
df[df.Other_Nominations_n_Recess_Appointments.str.contains("(?i)Declined", na=False)][['Full_Name','Other_Nominations_n_Recess_Appointments','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#                         Full_Name  \
# 1116   Herbert Stephenson Boreman
# 2031              James V. Allred
# 2392           Jed Joseph Johnson
# 1475       James William McCarthy
# 758        Frank Herbert Norcross
# 46              William Rufus Day
# 2334            Robert Paine Dick
# 2698         Solomon Lewis Withey
# 134   Henry Brockholst Livingston
# 118                Thomas Johnson
# 250                    Thomas Bee
# 115                      John Jay
# 120               William Cushing
#
#                 Other_Nominations_n_Recess_Appointments  \
# 1116  Received recess appointment to U.S. Court of A...
# 2031  Received recess appointment to U.S. District C...
# 2392  Nominated to U.S. Customs Court, March 29, 194...
# 1475  Nominated to U.S. District Court for the Distr...
# 758   Received recess appointment to U.S. Court of A...
# 46    Received recess appointment to U.S. District C...
# 2334  Received recess appointment to U.S. District C...
# 2698  Nominated to U.S. District Court for the Weste...
# 134   Received recess appointment to U.S. District C...
# 118   Nominated to U.S. District Court for the Distr...
# 250   Nominated to be chief judge of the U.S. Circui...
# 115   Nominated to be Chief Justice of the Supreme C...
# 120   Nominated to be Chief Justice of the Supreme C...
#
#      Appointing_President_1 Confirmation_Date_1
# 1116   Dwight D. Eisenhower          1959-06-16
# 2031         Harry S Truman          1949-10-12
# 2392         Harry S Truman          1947-06-23
# 1475        Calvin Coolidge          1929-01-08
# 758         Calvin Coolidge          1928-04-17
# 46       Theodore Roosevelt          1903-02-23
# 2334          Ulysses Grant          1872-06-07
# 2698        Abraham Lincoln          1863-03-11
# 134        Thomas Jefferson          1806-12-17
# 118       George Washington          1791-11-07
# 250       George Washington          1790-06-14
# 115       George Washington          1789-09-26
# 120       George Washington          1789-09-26

# %%
df[df.Other_Nominations_n_Recess_Appointments.str.contains("(?i)Rejected", na=False)][['Full_Name','Other_Nominations_n_Recess_Appointments','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#                            Full_Name  \
# 296                 Ronnie Lee White
# 1001               Robert Heron Bork
# 2104         George Harrold Carswell
# 1117  Clement Furman Haynsworth, Jr.
# 1109            John Johnston Parker
# 468                Ezekiel B. Turner
# 116                    John Rutledge
# 851             Maurice Neil Andrews
# 942                 Floyd H. Roberts
# 2289              Carroll O. Switzer
# 2394                Wallace McCamant
#
#                 Other_Nominations_n_Recess_Appointments  \
# 296   Nominated to U.S. District Court for the Easte...
# 1001  Nominated to Supreme Court of the United State...
# 2104  Nominated to Supreme Court of the United State...
# 1117  Nominated to Supreme Court of the United State...
# 1109  Nominated to Supreme Court of the United State...
# 468   Nominated to U.S. District Court for the North...
# 116   Nominated to be Chief Justice of the Supreme C...
# 851   Nominated to U.S. District Court for the North...
# 942   Nominated to U.S. District Court for the Weste...
# 2289  Nominated to U.S. District Court for the South...
# 2394  Nominated to U.S. Court of Appeals for the Nin...
#
#      Appointing_President_1 Confirmation_Date_1
# 296            Barack Obama          2014-07-16
# 1001          Ronald Reagan          1982-02-08
# 2104       Richard M. Nixon          1969-06-19
# 1117   Dwight D. Eisenhower          1957-04-04
# 1109        Calvin Coolidge          1925-12-14
# 468     Rutherford B. Hayes          1880-12-20
# 116       George Washington                 NaT
# 851          Harry S Truman                 NaT
# 942   Franklin D. Roosevelt                 NaT
# 2289         Harry S Truman                 NaT
# 2394        Calvin Coolidge                 NaT

# %%
df['Other_Nomination'] = df["Other_Nominations_n_Recess_Appointments"].str.findall(r"\b(nominated.*\d\d\d\d); .*", flags = re.I).dropna(0)
df['Other_Rejection'] = df["Other_Nominations_n_Recess_Appointments"].str.findall(r"\b(rejected.*\d\d\d\d).*", flags = re.I).dropna(0)
df[df.Other_Nominations_n_Recess_Appointments.str.contains(r"rejected", na=False, flags = re.I)][['Full_Name','Other_Nomination','Other_Rejection','Appointing_President_1','Confirmation_Date_1']].sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#                            Full_Name  \
# 296                 Ronnie Lee White
# 1001               Robert Heron Bork
# 2104         George Harrold Carswell
# 1117  Clement Furman Haynsworth, Jr.
# 1109            John Johnston Parker
# 468                Ezekiel B. Turner
# 116                    John Rutledge
# 851             Maurice Neil Andrews
# 942                 Floyd H. Roberts
# 2289              Carroll O. Switzer
# 2394                Wallace McCamant
#
#                                        Other_Nomination  \
# 296   [Nominated to U.S. District Court for the East...
# 1001  [Nominated to Supreme Court of the United Stat...
# 2104  [Nominated to Supreme Court of the United Stat...
# 1117  [Nominated to Supreme Court of the United Stat...
# 1109  [Nominated to Supreme Court of the United Stat...
# 468   [Nominated to U.S. District Court for the Nort...
# 116   [Nominated to be Chief Justice of the Supreme ...
# 851   [Nominated to U.S. District Court for the Nort...
# 942   [Nominated to U.S. District Court for the West...
# 2289  [Nominated to U.S. District Court for the Sout...
# 2394  [Nominated to U.S. Court of Appeals for the Ni...
#
#                                         Other_Rejection  \
# 296   [rejected by Senate, October 5, 1999; Nominate...
# 1001             [rejected by Senate, October 23, 1987]
# 2104                [rejected by Senate, April 8, 1970]
# 1117            [rejected by Senate, November 21, 1969]
# 1109                  [rejected by Senate, May 7, 1930]
# 468                 [rejected by Senate, April 2, 1879]
# 116   [rejected by Senate, December 15, 1795; resign...
# 851   [rejected by Senate, August 9, 1950; resigned,...
# 942   [rejected by Senate, February 6, 1939; resigne...
# 2289  [rejected by Senate, August 9, 1950; resigned,...
# 2394  [rejected by Senate, March 17, 1926; resigned,...
#
#      Appointing_President_1 Confirmation_Date_1
# 296            Barack Obama          2014-07-16
# 1001          Ronald Reagan          1982-02-08
# 2104       Richard M. Nixon          1969-06-19
# 1117   Dwight D. Eisenhower          1957-04-04
# 1109        Calvin Coolidge          1925-12-14
# 468     Rutherford B. Hayes          1880-12-20
# 116       George Washington                 NaT
# 851          Harry S Truman                 NaT
# 942   Franklin D. Roosevelt                 NaT
# 2289         Harry S Truman                 NaT
# 2394        Calvin Coolidge                 NaT

# %% [markdown]
# ### Confirmation Lengths

# %%
df['Confirmation_Duration_Total'] = df.Confirmation_Date_1 - df.Nomination_Date_1
df.Confirmation_Duration_Total.sort_values(ascending=False).describe()
# Out:
# count                       3444
# mean     75 days 11:20:16.724738
# std      81 days 12:26:06.705764
# min              0 days 00:00:00
# 25%             16 days 00:00:00
# 50%             45 days 00:00:00
# 75%            112 days 00:00:00
# max            639 days 00:00:00
# Name: Confirmation_Duration_Total, dtype: object

# %%
df.groupby(by='Appointing_President_1').Confirmation_Duration_Total.max().sort_values(ascending=False)
# Out:
# Appointing_President_1
# William J. Clinton      639 days
# Ronald Reagan           540 days
# Jimmy Carter            539 days
# George W. Bush          524 days
# Barack Obama            460 days
# Donald J. Trump         355 days
# George H.W. Bush        317 days
# Gerald Ford             317 days
# Dwight D. Eisenhower    254 days
# John F. Kennedy         248 days
# Zachary Taylor          224 days
# Lyndon B. Johnson       216 days
# Franklin D. Roosevelt   209 days
# Harry S Truman          195 days
# Richard M. Nixon        194 days
# Theodore Roosevelt      169 days
# Woodrow Wilson          125 days
# Benjamin Harrison       117 days
# John Quincy Adams       108 days
# Andrew Jackson          105 days
# Herbert Hoover           99 days
# Abraham Lincoln          92 days
# Grover Cleveland         81 days
# Ulysses Grant            73 days
# William McKinley         64 days
# James A. Garfield        59 days
# Calvin Coolidge          52 days
# William H. Taft          50 days
# Warren G. Harding        45 days
# Rutherford B. Hayes      44 days
# Andrew Johnson           35 days
# James Buchanan           34 days
# Chester A. Arthur        30 days
# Martin Van Buren         25 days
# Franklin Pierce          23 days
# James K. Polk            22 days
# Thomas Jefferson         20 days
# Millard Fillmore         18 days
# James Monroe             18 days
# John Tyler               10 days
# George Washington         7 days
# John Adams                7 days
# James Madison             4 days
# Name: Confirmation_Duration_Total, dtype: timedelta64[ns]

# %%
df.loc[df.Confirmation_Duration_Total.idxmax()][['Full_Name','Confirmation_Duration_Total','Appointing_President_1','Court_Name_1']]
# Out:
# Full_Name                                              William A. Fletcher
# Confirmation_Duration_Total                              639 days 00:00:00
# Appointing_President_1                                  William J. Clinton
# Court_Name_1                   U.S. Court of Appeals for the Ninth Circuit
# Name: 2451, dtype: object

# %%
df.loc[df.Party_of_Reappointing_President_1 != df.Party_of_Appointing_President_1][['Full_Name','Appointing_President_1','Reappointing_President_1','Recess_Appointment_Date_1','Nomination_Date_1','Confirmation_Date_1']].dropna().sort_values(by='Confirmation_Date_1', ascending=False)
# Out:
#              Full_Name Appointing_President_1 Reappointing_President_1  \
# 1141  Roger L. Gregory     William J. Clinton           George W. Bush
#
#      Recess_Appointment_Date_1 Nomination_Date_1 Confirmation_Date_1
# 1141                2000-12-27        2001-05-09          2001-07-20

# %% [markdown]
# ### Appointment Lengths

# %%
df['Service_Duration_1'] = df.Vacancy_Date - df.Commission_Date_1
df.Service_Duration_1.sort_values(ascending=False).describe()
# Out:
# count                         2699
# mean     7403 days 04:30:30.011115
# std      3965 days 08:35:00.648391
# min               21 days 00:00:00
# 25%             4490 days 00:00:00
# 50%             6915 days 00:00:00
# 75%            10162 days 00:00:00
# max            20245 days 00:00:00
# Name: Service_Duration_1, dtype: object

# %%
df.loc[df.Service_Duration_1.idxmax()][['Full_Name','Service_Duration_1','Appointing_President_1','Court_Name_1']]
# Out:
# Full_Name                                        William Joseph Nealon, Jr.
# Service_Duration_1                                      20245 days 00:00:00
# Appointing_President_1                                      John F. Kennedy
# Court_Name_1              U.S. District Court for the Middle District of...
# Name: 2665, dtype: object

# %%
df[(df.Appointing_President_1.str.contains(' W. ')) & (df.Termination_Date_1 < '20080115')][['Full_Name','Court_Type_1','Confirmation_Date_1','Termination_1','Termination_Date_1']].sort_values(by=['Confirmation_Date_1','Termination_Date_1'],ascending=[0,1])
# Out:
#                           Full_Name           Court_Type_1  \
# 1320            Susan Bieke Neilson  U.S. Court of Appeals
# 3190                Phillip S. Figa    U.S. District Court
# 2341        H[arold] Brent McKnight    U.S. District Court
# 1390               Michael Chertoff  U.S. Court of Appeals
# 2182                Paul G. Cassell    U.S. District Court
# 2118  Charles Willis Pickering, Sr.  U.S. Court of Appeals
#
#      Confirmation_Date_1 Termination_1 Termination_Date_1
# 1320          2005-10-27         Death         2006-01-25
# 3190          2003-10-02         Death         2008-01-05
# 2341          2003-07-31         Death         2004-11-27
# 1390          2003-06-09   Resignation         2005-02-15
# 2182          2002-05-13   Resignation         2007-11-05
# 2118                 NaT    Retirement         2004-12-08

# %%
df['Service_Duration_2'] = df[['Termination_Date_2','Senior_Status_Date_2']].max(axis=1) - df.Commission_Date_2
df.Service_Duration_2.sort_values(ascending=False).describe()
# Out:
# count                          412
# mean     3700 days 14:40:46.601941
# std      2733 days 11:17:06.951606
# min              161 days 00:00:00
# 25%             1478 days 00:00:00
# 50%             3398 days 00:00:00
# 75%             5342 days 06:00:00
# max            16447 days 00:00:00
# Name: Service_Duration_2, dtype: object

# %% [markdown]
# ### Demographics Breakdowns

# %%
### Appointments from President's home state = This can't be right

df[df.Birth_State.isin(df.Appointing_President_State_1)].groupby(by='Appointing_President_1').Appointing_President_State_1.value_counts().sort_values(ascending=False)
# Out:
# Appointing_President_1  Appointing_President_State_1
# Ronald Reagan           CA                              225
# William J. Clinton      AK                              218
# George W. Bush          TX                              194
# Barack Obama            IL                              194
# Jimmy Carter            GA                              143
# Richard M. Nixon        CA                              128
# George H.W. Bush        TX                              112
# Franklin D. Roosevelt   NY                              102
# Dwight D. Eisenhower    KS                               91
# Harry S Truman          MO                               78
# Lyndon B. Johnson       TX                               75
# Donald J. Trump         NY                               71
# John F. Kennedy         MA                               59
# Calvin Coolidge         MA                               43
# Theodore Roosevelt      NY                               40
# Woodrow Wilson          NJ                               38
# Grover Cleveland        NY                               36
# Herbert Hoover          CA                               33
# Gerald Ford             MI                               32
# William H. Taft         OH                               30
# Warren G. Harding       OH                               28
# Benjamin Harrison       IN                               18
# Ulysses Grant           IL                               18
# Chester A. Arthur       NY                               14
# William McKinley        OH                               14
# Franklin Pierce         NH                               10
# Abraham Lincoln         IL                                9
# George Washington       VA                                8
# James Monroe            VA                                7
# John Quincy Adams       MA                                7
# Martin Van Buren        NY                                7
# Rutherford B. Hayes     OH                                7
# Andrew Jackson          TN                                7
# James Buchanan          PA                                6
# Thomas Jefferson        VA                                5
# James K. Polk           TN                                5
# John Tyler              VA                                4
# James A. Garfield       OH                                3
# James Madison           VA                                3
# John Adams              MA                                3
# Andrew Johnson          TN                                3
# Millard Fillmore        NY                                2
# Name: Appointing_President_State_1, dtype: int64

# %%
df.groupby(by='Party_of_Appointing_President_1').Gender.value_counts(1)
# Out:
# Party_of_Appointing_President_1  Gender
# Democratic                       Male      0.829149
#                                  Female    0.170851
# Federalist                       Male      1.000000
# Jeffersonian Republican          Male      1.000000
# Republican                       Male      0.912450
#                                  Female    0.087550
# Whig                             Male      1.000000
# Name: Gender, dtype: float64

# %%
df.groupby(by='Party_of_Appointing_President_1').Race_or_Ethnicity.value_counts()
# Out:
# Party_of_Appointing_President_1  Race_or_Ethnicity
# Democratic                       White                              1368
#                                  AfriAmerican                        161
#                                  Hispanic                             69
#                                  Asian American                       23
#                                  AmeriIndian                           3
#                                  AfriAmerican/Hispanic                 2
#                                  Asian American/Pacific Islander       2
#                                  Hispanic/White                        2
#                                  AfriAmerican/White                    1
#                                  Asian American/Hispanic               1
#                                  Asian American/White                  1
# Federalist                       White                                 6
# Jeffersonian Republican          White                                35
# Republican                       White                              1637
#                                  Hispanic                             55
#                                  AfriAmerican                         50
#                                  Asian American                       16
#                                  Pacific Islander/White                1
# Whig                             White                                11
# Name: Race_or_Ethnicity, dtype: int64

# %%
df[(df.Party_of_Appointing_President_1 == 'Democratic') | (df.Party_of_Appointing_President_1 == 'Republican')] \
    .groupby(by='Party_of_Appointing_President_1').Race_or_Ethnicity.value_counts(1).unstack().fillna(0) \
    .plot(kind='bar', width=.9, figsize=(18, 10))
plt.tight_layout()

# %%
ax = df[(df.Party_of_Appointing_President_1 == 'Democratic') | (df.Party_of_Appointing_President_1 == 'Republican')] \
    .groupby(by='Party_of_Appointing_President_1').Race_or_Ethnicity.value_counts(1).unstack().fillna(0) \
    .plot(kind='barh', stacked=True, width=.7, figsize=(18, 8))
plt.legend(loc='center', ncol=6, columnspacing=2)
plt.tight_layout()

# %%
df['Appointment_Age_1'] =  ((df.Nomination_Date_1 - df.Birth_Date)/np.timedelta64(1, 'Y'))
df.Appointment_Age_1.sort_values(ascending=False).describe()
# Out:
# count    3461.000000
# mean       51.116766
# std         6.891250
# min        25.347543
# 25%        46.276104
# 50%        51.272785
# 75%        56.138045
# max        71.284147
# Name: Appointment_Age_1, dtype: float64

# %%
df.loc[df.Appointment_Age_1.idxmax()][['Full_Name','Appointment_Age_1','Appointing_President_1','Court_Name_1']]
# Out:
# Full_Name                 William Raymond Green
# Appointment_Age_1                       71.2841
# Appointing_President_1          Calvin Coolidge
# Court_Name_1                    Court of Claims
# Name: 16, dtype: object

# %%
df.loc[df.Appointment_Age_1.idxmin()][['Full_Name','Appointment_Age_1','Appointing_President_1','Court_Name_1']]
# Out:
# Full_Name                                          Thomas Jefferson Boynton
# Appointment_Age_1                                                   25.3475
# Appointing_President_1                                      Abraham Lincoln
# Court_Name_1              U.S. District Court for the Southern District ...
# Name: 2235, dtype: object

# %%
df['Appointment_Age_Earliest'] = ((df[['Nomination_Date_1','Nomination_Date_2','Nomination_Date_3','Nomination_Date_4','Nomination_Date_5']].min(axis=1) - df.Birth_Date)/np.timedelta64(1, 'Y'))
df.loc[df.Appointment_Age_Earliest.idxmin()][['Full_Name','Appointment_Age_Earliest']]
# Out:
# Full_Name                   Thomas Jefferson Boynton
# Appointment_Age_Earliest                     25.3475
# Name: 2235, dtype: object

# %%
df.loc[(df.Appointment_Age_1.idxmin()) & (df.Court_Type_1 == 'Supreme Court')][['Full_Name','Appointment_Age_1']].sort_values(by='Appointment_Age_1').head()
# Out:
#                    Full_Name  Appointment_Age_1
# 141             Joseph Story          32.156718
# 135     William Johnson, Jr.          32.233379
# 126       Bushrod Washington          36.540107
# 124            James Iredell          38.347126
# 55   William Orville Douglas          40.422459

# %% [markdown]
# ### Professional Background

# %%
df.Professional_Career.head()
# Out:
# 0    Private practice, Accomack County, Virginia, 1...
# 1    Private practice, Charlestown, New Hampshire, ...
# 2    Private practice, Indiana Territory, 1812-1813...
# 3    Private practice and master in chancery, Suffo...
# 4    Private practice, Bloomington and Bedford, Ind...
# Name: Professional_Career, dtype: object

# %%
df.Professional_Career = df.Professional_Career.astype(str)
# Counter(" ".join(df.Professional_Career).lower().split()).most_common(60)
pd.Series(' '.join(df.Professional_Career).lower().split()).value_counts().head(60)
# Out:
# of               6472
# private          4180
# practice,        4147
# u.s.             3893
# district         2264
# attorney,        1863
# the              1849
# assistant        1774
# new              1705
# judge,           1451
# court            1415
# court,           1261
# law              1257
# state            1207
# judicial         1101
# attorney          939
# clerk,            924
# county,           876
# hon.              809
# and               803
# for               795
# county            745
# member,           715
# california,       697
# justice,          654
# united            635
# law,              618
# counsel,          614
# states,           581
# university        567
# circuit,          561
# army              558
# general,          550
# york,             540
# pennsylvania,     535
# texas,            484
# supreme           482
# department        478
# york              474
# deputy            471
# city,             461
# conference        454
# washington,       447
# city              442
# special           437
# illinois,         407
# professor,        381
# general           377
# circuit           374
# jersey,           345
# appeals           337
# virginia,         335
# chief             335
# division,         332
# florida,          328
# ohio,             317
# adjunct           311
# superior          308
# associate         298
# carolina,         297
# dtype: int64

# %%
df[df.Professional_Career.str.contains('army|navy|marine|force', na=False, flags = re.I)].groupby(by='Appointing_President_1').size().sort_values(ascending=False).head(15)
# Out:
# Appointing_President_1
# Ronald Reagan            175
# Jimmy Carter             152
# Richard M. Nixon         132
# Lyndon B. Johnson         85
# George H.W. Bush          69
# William J. Clinton        67
# George W. Bush            55
# Dwight D. Eisenhower      55
# Franklin D. Roosevelt     46
# Harry S Truman            43
# John F. Kennedy           39
# Gerald Ford               37
# Grover Cleveland          28
# Barack Obama              28
# Donald J. Trump           16
# dtype: int64

# %%
search_terms = ['professor','lecturer','faculty','dean']
df[df.Professional_Career.str.contains('|'.join(search_terms),na=False,case=False)].groupby(by='Appointing_President_1').size().sort_values(ascending=False).head(15)
# Out:
# Appointing_President_1
# William J. Clinton       87
# George W. Bush           68
# Ronald Reagan            66
# Jimmy Carter             55
# Barack Obama             45
# Donald J. Trump          34
# Franklin D. Roosevelt    25
# George H.W. Bush         24
# Richard M. Nixon         23
# Lyndon B. Johnson        20
# Dwight D. Eisenhower     15
# Harry S Truman           12
# John F. Kennedy           8
# Grover Cleveland          8
# William H. Taft           7
# dtype: int64

# %%
### Gave up trying to roll my own, found a ngrams library online

from sklearn.feature_extraction.text import CountVectorizer
word_vectorizer = CountVectorizer(ngram_range=(2,2), analyzer='word')
sparse_matrix = word_vectorizer.fit_transform(df.Professional_Career)
frequencies = sum(sparse_matrix).toarray()[0]
pd.DataFrame(frequencies, index=word_vectorizer.get_feature_names(), columns=['frequency']).sort_values(by='frequency', ascending=False).head(20)
# Out:
#                     frequency
# private practice         4153
# court of                 1355
# district of              1340
# new york                 1059
# of the                    964
# assistant attorney        918
# law clerk                 861
# clerk hon                 774
# for the                   625
# united states             623
# the united                621
# attorney general          573
# of law                    572
# district court            560
# department of             472
# state of                  469
# supreme court             454
# conference of             449
# of new                    446
# new jersey                420

# %%
from sklearn.feature_extraction.text import CountVectorizer
word_vectorizer = CountVectorizer(ngram_range=(3,4), analyzer='word')
sparse_matrix = word_vectorizer.fit_transform(df.Professional_Career)
frequencies = sum(sparse_matrix).toarray()[0]
pd.DataFrame(frequencies, index=word_vectorizer.get_feature_names(), columns=['frequency']).sort_values(by='frequency', ascending=False).head(20)
# Out:
#                                frequency
# law clerk hon                        772
# of the united                        616
# the united states                    615
# of the united states                 614
# conference of the united             413
# conference of the                    413
# judicial conference of               410
# judicial conference of the           410
# court of appeals                     385
# member judicial conference           368
# member judicial conference of        368
# private practice new                 359
# new york city                        346
# supreme court of                     321
# attorney for the                     315
# department of justice                304
# general state of                     280
# of new york                          279
# court of appeals for                 264
# of appeals for                       264

# %% [markdown]
# ### Education

# %%
lastreadlaw = [df[df['School_1'] == 'Read law'].Degree_Year_1.max(),
               df[df['School_2'] == 'Read law'].Degree_Year_3.max(), 
               df[df['School_3'] == 'Read law'].Degree_Year_3.max(),
               df[df['School_4'] == 'Read law'].Degree_Year_4.max(), 
               df[df['School_5'] == 'Read law'].Degree_Year_5.max()
              ]
lastreadlaw
# Out:
# [Timestamp('1934-01-01 00:00:00'),
#  Timestamp('1925-01-01 00:00:00'),
#  Timestamp('1930-01-01 00:00:00'),
#  Timestamp('1927-01-01 00:00:00'),
#  Timestamp('1910-01-01 00:00:00')]

# %%
allschool_df = df[['Full_Name','Appointing_President_1','Party_of_Appointing_President_1']]
allschool_df['Schl1'] = df.School_1 + '-777777777-' + df.Degree_1.fillna('nun') + '-999999999-' + df.Degree_Year_1.astype(str).fillna('nun')
allschool_df['Schl2'] = df.School_2 + '-777777777-' + df.Degree_2.fillna('nun') + '-999999999-' + df.Degree_Year_2.astype(str).fillna('nun')
allschool_df['Schl3'] = df.School_3 + '-777777777-' + df.Degree_3.fillna('nun') + '-999999999-' + df.Degree_Year_3.astype(str).fillna('nun')
allschool_df['Schl4'] = df.School_4 + '-777777777-' + df.Degree_4.fillna('nun') + '-999999999-' + df.Degree_Year_4.astype(str).fillna('nun')
allschool_df['Schl5'] = df.School_5 + '-777777777-' + df.Degree_5.fillna('nun') + '-999999999-' + df.Degree_Year_5.astype(str).fillna('nun')
# Out:
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Program Files (x86)\Python37-32\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
allschool_df = allschool_df.melt(id_vars =['Full_Name','Appointing_President_1','Party_of_Appointing_President_1'], value_vars =['Schl1','Schl2','Schl3','Schl4','Schl5'], var_name='Degree_Number', value_name='School')

# %%
allschool_df.Degree_Number.replace(r'Schl',r'',regex=True,inplace=True)
allschool_df['Degree'] = allschool_df.School.str.extract('-777777777-(.*)-999999999-', expand=False)
allschool_df['Degree_Year'] = allschool_df.School.str.extract('.*-999999999-(.*)$', expand=False)
allschool_df['School'] = allschool_df.School.str.extract(r'(.*)-777777777-.*', expand=False)
allschool_df['DYear'] = allschool_df.Degree_Year.str.extract('^(\d\d\d\d).*', expand=False)
allschool_df.replace('nun',np.nan,inplace=True)
allschool_df.Degree_Year = allschool_df.Degree_Year.astype('datetime64[ns]')

# %%
allschool_df.head(15)
# Out:
#                        Full_Name Appointing_President_1  \
# 0        George Parker Scarburgh        Franklin Pierce
# 1           John James Gilchrist        Franklin Pierce
# 2         Isaac Newton Blackford        Franklin Pierce
# 3           Edward Greely Loring         James Buchanan
# 4                   James Hughes         James Buchanan
# 5   John Chandler Bancroft Davis      Chester A. Arthur
# 6                Lawrence Weldon      Chester A. Arthur
# 7       William Adams Richardson      Chester A. Arthur
# 8                     John Davis      Chester A. Arthur
# 9         George Wesley Atkinson     Theodore Roosevelt
# 10        Stanton Judkins Peelle     Theodore Roosevelt
# 11        Samuel Stebbins Barney     Theodore Roosevelt
# 12                     James Hay         Woodrow Wilson
# 13            George Eddy Downey         Woodrow Wilson
# 14        Edward Kernan Campbell         Woodrow Wilson
#
#    Party_of_Appointing_President_1 Degree_Number  \
# 0                       Democratic             1
# 1                       Democratic             1
# 2                       Democratic             1
# 3                       Democratic             1
# 4                       Democratic             1
# 5                       Republican             1
# 6                       Republican             1
# 7                       Republican             1
# 8                       Republican             1
# 9                       Republican             1
# 10                      Republican             1
# 11                      Republican             1
# 12                      Democratic             1
# 13                      Democratic             1
# 14                      Democratic             1
#
#                                                School Degree Degree_Year DYear
# 0                      Read law with Thomas R. Joynes    NaN  1827-01-01  1827
# 1                                     Harvard College    NaN  1828-01-01  1828
# 2    College of New Jersey (now Princeton University)    NaN  1806-01-01  1806
# 3                                     Harvard College   A.B.  1821-01-01  1821
# 4                                  Indiana University    NaN         NaT   NaN
# 5                                            Read law    NaN  1844-01-01  1844
# 6                                                 NaN    NaN         NaT   NaN
# 7                                     Harvard College   A.B.  1843-01-01  1843
# 8                                 University of Paris    NaN         NaT   NaN
# 9                            Ohio Wesleyan University   A.B.  1870-01-01  1870
# 10                       Winchester Seminary, Indiana    NaN         NaT   NaN
# 11               Lombard College, Galesburg, Illinois    NaN         NaT   NaN
# 12                         University of Pennsylvania    NaN         NaT   NaN
# 13  Indiana Asbury University (now DePauw University)   B.A.  1880-01-01  1880
# 14                             University of Virginia    NaN         NaT   NaN

# %%
allschool_df['School_Neat'] = allschool_df['School']
allschool_df.School_Neat.replace(r'.*\(now (.*)\)',r'\1',regex=True,inplace=True)
allschool_df.replace({'School_Neat':{
    'College of':'Cof',
    ' College':'',
    'University of':'Uof',
    ' University':'',
    ' Department':'',
    ' Faculty':'',
    ' School':'',
    ' Center':'',
    ' of Law':'',
    ' Law':'',
    ' of Jurisprudence':'',
    ' of Business':'',
    ' Business':'',
    ' Administration':'',
    ' Wharton':'',
    ' Gould':'',
    ', Boalt Hall':'',
    ', Paul M. Hebert':'',
    '-Kansas City':'',
    ' -- Newark':'',
    ' -- Camden':'',
    '  ':' '
}},regex=True,inplace=True)
allschool_df.School_Neat.replace(r'\s?Cof','',regex=True,inplace=True)
allschool_df.School_Neat.replace(r'\s?$','',regex=True,inplace=True)
allschool_df.School_Neat.replace(r',$','',regex=True,inplace=True)
allschool_df.School_Neat.value_counts().head(60)
# Out:
# Harvard                        470
# Read law                       444
# Yale                           277
# Uof Michigan                   177
# Uof Virginia                   168
# Columbia                       155
# Uof Texas                      148
# Georgetown                     126
# Uof Pennsylvania               115
# Stanford                       102
# Princeton                       99
# New York                        89
# Uof California, Berkeley        85
# Uof Florida                     73
# Uof Chicago                     71
# George Washington               66
# Cornell                         64
# Uof Alabama                     62
# Northwestern                    61
# Louisiana State                 61
# Uof Missouri                    60
# Uof Oklahoma                    57
# Rutgers                         53
# Uof Georgia                     53
# Uof North Carolina              52
# Duke                            51
# Uof Iowa                        50
# Vanderbilt                      49
# Uof Arkansas                    49
# Tulane                          49
# Uof California, Los Angeles     48
# Boston                          48
# Fordham                         46
# Uof South Carolina              44
# Uof Southern California         44
# Uof Wisconsin                   43
# Washington and Lee              42
# Uof Minnesota                   42
# Dartmouth                       41
# Uof Arizona                     41
# West Virginia                   40
# Uof Illinois                    40
# Uof Kansas                      39
# Howard                          39
# Emory                           39
# Temple                          38
# Uof Mississippi                 37
# Uof Washington                  36
# Uof Notre Dame                  35
# Dickinson                       32
# Ohio State                      32
# Uof Tennessee                   30
# Uof Cincinnati                  30
# Uof Kentucky                    29
# Notre Dame                      29
# Brown                           28
# Uof Pittsburgh                  28
# Syracuse                        26
# St. Louis                       26
# Wake Forest                     26
# Name: School_Neat, dtype: int64

# %%
ax = allschool_df.School_Neat.value_counts().head(30).plot(kind='barh', figsize=(18, 8), y='School_Neat').invert_yaxis()
plt.tight_layout()

# %%
ax = allschool_df.groupby(['DYear']).School_Neat.value_counts().unstack().plot(figsize=(18, 8))
ax.get_legend().remove()

# %%
def build_colors(row):
    if row['School_Neat'] == 'Read law':
        return 'green'
    elif row['School_Neat'] == 'Harvard':
        return 'crimson'
    else:
        return 'lightgrey'
colors = allschool_df.reset_index().apply(build_colors, axis=1)

ax = allschool_df.groupby(['DYear']).School_Neat.value_counts().unstack().plot(figsize=(18, 8), color=colors)
ax.get_legend().remove()

# %%
# tops = allschool_df.School_Neat.value_counts().head(20)
# allschool_df[[allschool_df.School_Neat == 'Harvard']].groupby(by='DYear').count()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-7ed2a8035195> in <module>
#       1 tops = allschool_df.School_Neat.value_counts().head(20)
# ----> 2 allschool_df[[allschool_df.School_Neat == 'Harvard']].groupby(by='DYear').count()
#
# C:\Program Files (x86)\Python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# C:\Program Files (x86)\Python37-32\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2961         elif len(key) != len(self.index):
#    2962             raise ValueError('Item wrong length %d instead of %d.' %
# -> 2963                              (len(key), len(self.index)))
#    2964
#    2965         # check_bool_indexer will throw exception if Series key cannot
#
# ValueError: Item wrong length 1 instead of 17325.

# %%
allschool_df.groupby(by='Party_of_Appointing_President_1').School_Neat.value_counts(1)
# Out:
# Party_of_Appointing_President_1  School_Neat
# Democratic                       Harvard                                  0.070723
#                                  Read law                                 0.050649
#                                  Yale                                     0.041075
#                                  Columbia                                 0.025633
#                                  Uof Texas                                0.024707
#                                  Uof Virginia                             0.022854
#                                  Uof Michigan                             0.021309
#                                  Georgetown                               0.020692
#                                  Uof California, Berkeley                 0.014824
#                                  Stanford                                 0.014515
#                                  Uof Florida                              0.014515
#                                  Uof Pennsylvania                         0.013589
#                                  New York                                 0.012662
#                                  Louisiana State                          0.012044
#                                  Uof Missouri                             0.012044
#                                  Princeton                                0.011427
#                                  Uof Chicago                              0.011427
#                                  Boston                                   0.010500
#                                  George Washington                        0.010191
#                                  Uof Oklahoma                             0.009883
#                                  Howard                                   0.009574
#                                  Rutgers                                  0.008956
#                                  Uof Arkansas                             0.008338
#                                  Uof Georgia                              0.008338
#                                  Cornell                                  0.008030
#                                  Uof Wisconsin                            0.008030
#                                  Fordham                                  0.007721
#                                  Uof California, Los Angeles              0.007721
#                                  Vanderbilt                               0.007412
#                                  Northwestern                             0.007103
#                                                                             ...
# Republican                       Uof Texas at El Paso                     0.000282
#                                  Uof Texas, LBJ of Public Affairs         0.000282
#                                  Uof Western Kentucky                     0.000282
#                                  Uof Western Ontario                      0.000282
#                                  Uof Wisconsin, Milwaukee                 0.000282
#                                  Uof the Pacific                          0.000282
#                                  Ursinus                                  0.000282
#                                  Utah State                               0.000282
#                                  Washington, Chestertown, Maryland        0.000282
#                                  West Virginia Institute of Technology    0.000282
#                                  West Virginia Wesleyan                   0.000282
#                                  Western Kentucky                         0.000282
#                                  Western Michigan                         0.000282
#                                  Western Michigan, Honors                 0.000282
#                                  Western State Colorado                   0.000282
#                                  Westfield State Teachers                 0.000282
#                                  Westminster, Fulton, Missouri            0.000282
#                                  Whitworth                                0.000282
#                                  Wichita State                            0.000282
#                                  Wilkes                                   0.000282
#                                  William Carey                            0.000282
#                                  Williston Northampton                    0.000282
#                                  Winchester Seminary, Indiana             0.000282
#                                  Yeshiva, Benjamin N. Cardozo             0.000282
# Whig                             Read law                                 0.529412
#                                  Harvard                                  0.235294
#                                  Litchfield (Tapping Reeve)               0.058824
#                                  Middlebury                               0.058824
#                                  Uof South Carolina                       0.058824
#                                  Uof Virginia                             0.058824
# Name: School_Neat, Length: 1058, dtype: float64

# %%
allschool_df.Degree.value_counts().head(20)
# Out:
# J.D.          1667
# B.A.          1368
# LL.B.         1264
# A.B.           731
# B.S.           409
# LL.M.          129
# M.A.           121
# B.B.A.          57
# A.M.            53
# A.A.            45
# Ph.B.           31
# M.S.            17
# M.B.A.          16
# Ph.D.           13
# B.S.B.A.        10
# M.P.A.           9
# B.S.L.           7
# B.L.             7
# S.J.D.           6
# B.A., B.S.       6
# Name: Degree, dtype: int64

# %%
allschool_df['Degree_Neat'] = allschool_df['Degree']
allschool_df.replace({'Degree_Neat':{
    ', letters':'',
    ', business':'',
    ', economics':'',
    ', commerce':'',
    ', law':'',
    ', judicial studies':'',
    ', judicial process':'',
    ', politiphilosophy':'',
    ', civil engineering':'',
    ' of Completion':'',
    ' in Law':'',
    ' in English Law':'',
    ' in Legal Studies':'',
    ' in Jurisprudence':'',
    ' in Social Science':'',
    ' in Dispute Resolution':'',
    ' in Regulatory Economics':'',
    ' in International Arbitration':'',
    ' in Foreign and Comparative Law':'',
    ', Certificate of Business Studies':'',
    'Civil Mediator ':'',
}},regex=True,inplace=True)
allschool_df.replace({'Degree_Neat':{
    'D.Phil.':'Ph.D.',
    'A.B.':'B.A.',
    'A.M.':'M.A.',
    'B.L.':'LL.B.',
    'B.M.A.':'B.A.',
    'J.S.D.':'S.J.D.',
    'B.S.B.A.':'B.B.A.',
    'B.S.C.E.':'B.S.',
    'B.S.E.E.':'B.S.',
    'B.S.E.':'B.S.',
    'B.E.E.':'B.S.',
    'B.S.Ag.E.':'B.S.',
    'B.Sc.':'B.S.',
    'M.Sc.':'M.S.',
    'M.C.S.':'M.S.',
    '..':'',
    '  ':' '
}},regex=False,inplace=True)
allschool_df.Degree_Neat.value_counts().head(30)
# Out:
# B.A.           2104
# J.D.           1667
# LL.B.          1271
# B.S.            426
# M.A.            174
# LL.M.           133
# B.B.A.           67
# A.A.             45
# Ph.B.            31
# M.S.             21
# M.B.A.           16
# Ph.D.            16
# M.P.A.            9
# S.J.D.            8
# B.S.L.            7
# Certificate       6
# Diploma           6
# B.A., B.S.        6
# Litt.B.           5
# B.S.F.S.          4
# M.Phil.           4
# M.S.W.            4
# M.Ed.             3
# M.Litt.           3
# M.J.S.            3
# M.A.T.            3
# B.C.S.            2
# M.L.S.            2
# B.Litt.           2
# Ph.G.             2
# Name: Degree_Neat, dtype: int64

# %%
# def build_colors(row):
#     if row['Degree_Neat'] == 'J.D.':
#         return 'green'
#     elif row['Degree_Neat'] == 'LL.M.':
#         return 'blue'
#     elif row['Degree_Neat'] == 'LL.B.':
#         return 'gold'
#     else:
#         return 'lightgrey'

# colors = allschool_df.reset_index().apply(build_colors, axis=1)

ax = allschool_df.groupby(by='DYear').Degree_Neat.value_counts().unstack().plot(figsize=(18, 10), kind='line')
plt.legend(ncol=6, columnspacing=2)
ax.get_xlim()
ax.set_xlim(100, 182)
ax.yaxis.grid(linewidth=0.25)

# %%
allschool_df.to_csv('sources/schooling_hist.csv', index=False)

# %% [markdown]
# # Possible Deletions

# %% [markdown]
# ### Mostly Useless Info

# %%
df = df.drop(['nid','jid', 
              'Seat_ID_1','Reappointing_President_1','Party_of_Reappointing_President_1','Statute_Authorizing_New_Seat_1','Service_as_Chief_Judge_Begin_1','Service_as_Chief_Judge_End_1','2nd_Service_as_Chief_Judge_Begin_1','2nd_Service_as_Chief_Judge_End_1',
#               'Seat_ID_2','Reappointing_President_2','Party_of_Reappointing_President_2','Statute_Authorizing_New_Seat_2','Service_as_Chief_Judge_Begin_2','Service_as_Chief_Judge_End_2','2nd_Service_as_Chief_Judge_Begin_2','2nd_Service_as_Chief_Judge_End_2',
#               'Seat_ID_3','Reappointing_President_3','Party_of_Reappointing_President_3','Statute_Authorizing_New_Seat_3','Service_as_Chief_Judge_Begin_3','Service_as_Chief_Judge_End_3','3nd_Service_as_Chief_Judge_Begin_3','3nd_Service_as_Chief_Judge_End_3',
#               'Seat_ID_4','Reappointing_President_4','Party_of_Reappointing_President_4','Statute_Authorizing_New_Seat_4','Service_as_Chief_Judge_Begin_4','Service_as_Chief_Judge_End_4','4nd_Service_as_Chief_Judge_Begin_4','4nd_Service_as_Chief_Judge_End_4',
#               'Seat_ID_5','Reappointing_President_5','Party_of_Reappointing_President_5','Statute_Authorizing_New_Seat_5','Service_as_Chief_Judge_Begin_5','Service_as_Chief_Judge_End_5','5nd_Service_as_Chief_Judge_Begin_5','5nd_Service_as_Chief_Judge_End_5',
#               'Seat_ID_6','Reappointing_President_6','Party_of_Reappointing_President_6','Statute_Authorizing_New_Seat_6','Service_as_Chief_Judge_Begin_6','Service_as_Chief_Judge_End_6','6nd_Service_as_Chief_Judge_Begin_6','6nd_Service_as_Chief_Judge_End_6'
             ], axis=1)

# %% [markdown]
# ### Complex Strings Requiring Detailed Parsing

# %%
df = df.drop(['Other_Federal_Judicial_Service_1','Other_Federal_Judicial_Service_2','Other_Federal_Judicial_Service_3','Other_Federal_Judicial_Service_4',
              'Professional_Career','Other_Nominations_n_Recess_Appointments'
             ], axis=1)

# %% [markdown]
# ### If Concerned Only with Last Positions Held

# %%
df = df.drop([
    'Court_Type_2','Court_Name_2','Appointment_Title_2','Appointing_President_2','Party_of_Appointing_President_2','Reappointing_President_2','Party_of_Reappointing_President_2','ABA_Rating_2','Seat_ID_2','Statute_Authorizing_New_Seat_2','Recess_Appointment_Date_2','Nomination_Date_2','Committee_Referral_Date_2','Hearing_Date_2','Judiciary_Committee_Action_2','Committee_Action_Date_2','Senate_Vote_Type_2','Ayes_n_Nays_2','Confirmation_Date_2','Commission_Date_2','Service_as_Chief_Judge_Begin_2','Service_as_Chief_Judge_End_2','2nd_Service_as_Chief_Judge_Begin_2','2nd_Service_as_Chief_Judge_End_2','Senior_Status_Date_2','Termination_2','Termination_Date_2',
    'Court_Type_3','Court_Name_3','Appointment_Title_3','Appointing_President_3','Party_of_Appointing_President_3','Reappointing_President_3','Party_of_Reappointing_President_3','ABA_Rating_3','Seat_ID_3','Statute_Authorizing_New_Seat_3','Recess_Appointment_Date_3','Nomination_Date_3','Committee_Referral_Date_3','Hearing_Date_3','Judiciary_Committee_Action_3','Committee_Action_Date_3','Senate_Vote_Type_3','Ayes_n_Nays_3','Confirmation_Date_3','Commission_Date_3','Service_as_Chief_Judge_Begin_3','Service_as_Chief_Judge_End_3','2nd_Service_as_Chief_Judge_Begin_3','2nd_Service_as_Chief_Judge_End_3','Senior_Status_Date_3','Termination_3','Termination_Date_3',
    'Court_Type_4','Court_Name_4','Appointment_Title_4','Appointing_President_4','Party_of_Appointing_President_4','Reappointing_President_4','Party_of_Reappointing_President_4','ABA_Rating_4','Seat_ID_4','Statute_Authorizing_New_Seat_4','Recess_Appointment_Date_4','Nomination_Date_4','Committee_Referral_Date_4','Hearing_Date_4','Judiciary_Committee_Action_4','Committee_Action_Date_4','Senate_Vote_Type_4','Ayes_n_Nays_4','Confirmation_Date_4','Commission_Date_4','Service_as_Chief_Judge_Begin_4','Service_as_Chief_Judge_End_4','2nd_Service_as_Chief_Judge_Begin_4','2nd_Service_as_Chief_Judge_End_4','Senior_Status_Date_4','Termination_4','Termination_Date_4',
    'Court_Type_5','Court_Name_5','Appointment_Title_5','Appointing_President_5','Party_of_Appointing_President_5','Reappointing_President_5','Party_of_Reappointing_President_5','ABA_Rating_5','Seat_ID_5','Statute_Authorizing_New_Seat_5','Recess_Appointment_Date_5','Nomination_Date_5','Committee_Referral_Date_5','Hearing_Date_5','Judiciary_Committee_Action_5','Committee_Action_Date_5','Senate_Vote_Type_5','Ayes_n_Nays_5','Confirmation_Date_5','Commission_Date_5','Service_as_Chief_Judge_Begin_5','Service_as_Chief_Judge_End_5','2nd_Service_as_Chief_Judge_Begin_5','2nd_Service_as_Chief_Judge_End_5','Senior_Status_Date_5','Termination_5','Termination_Date_5',
    'Court_Type_6','Court_Name_6','Appointment_Title_6','Appointing_President_6','Party_of_Appointing_President_6','Reappointing_President_6','Party_of_Reappointing_President_6','ABA_Rating_6','Seat_ID_6','Statute_Authorizing_New_Seat_6','Recess_Appointment_Date_6','Nomination_Date_6','Committee_Referral_Date_6','Hearing_Date_6','Judiciary_Committee_Action_6','Committee_Action_Date_6','Senate_Vote_Type_6','Ayes_n_Nays_6','Confirmation_Date_6','Commission_Date_6','Service_as_Chief_Judge_Begin_6','Service_as_Chief_Judge_End_6','2nd_Service_as_Chief_Judge_Begin_6','2nd_Service_as_Chief_Judge_End_6','Senior_Status_Date_6','Termination_6','Termination_Date_6'
], axis=1)

# %% [markdown]
# ### If Concerned Only with Positions Currently Held

# %%
# df = df[pd.isna(df['Termination_1'])]

# %% [markdown]
# ### If Concerned Only with Positions Currently and Actively Held (No Senior Status)

# %%
# df = df[pd.isna(df['Termination_1'])]
# df = df[pd.isna(df['Senior_Status_Date_1'])]

# %% [markdown]
# ### Delete Extranious Court Jurisdictions

# %%
###  SUPREME COURT
df.drop(df[df.Court_Type_1 == 'Supreme Court'].index, inplace=True)

# ###  CIRCUIT COURTS OF APPEALS
# df.drop(df[df.Court_Type_1 == 'U.S. Court of Appeals'].index, inplace=True)

# ###  DISTRICT COURTS
# df.drop(df[df.Court_Type_1 == 'U.S. District Court'].index, inplace=True)

###  OTHER (Court of International Trade)
df.drop(df[df.Court_Type_1 == 'Other'].index, inplace=True)

# %%
df.Court_Type_1.value_counts()

# %% [markdown]
# # Export

# %%
### Turn Datetime years (with no month/day data) back to string
# df.Degree_Year_1 = df.Degree_Year_1.dt.year.astype(str).str.replace(r'.0','')
# df.Degree_Year_2 = df.Degree_Year_2.dt.year.astype(str).str.replace(r'.0','')
# df.Degree_Year_3 = df.Degree_Year_3.dt.year.astype(str).str.replace(r'.0','')
# df.Degree_Year_4 = df.Degree_Year_4.dt.year.astype(str).str.replace(r'.0','')
# df.Degree_Year_5 = df.Degree_Year_5.dt.year.astype(str).str.replace(r'.0','')

# %%
df.to_csv('sources/judges_pandaX1.csv', date_format='%Y-%m-%d', index=False)

# %%
# df.profile_report()
