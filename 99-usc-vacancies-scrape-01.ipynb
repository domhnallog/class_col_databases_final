# %%
import requests
import re
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
my_url = "https://www.uscourts.gov/judges-judgeships/judicial-vacancies/current-judicial-vacancies"
raw_html = requests.get(my_url).content
soup_doc = BeautifulSoup(raw_html, "html.parser")
print(type(soup_doc))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
### TEST VIEWS OF DATA
# raw_html
# print(soup_doc)
print(soup_doc.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!-->
# <html dir="ltr" lang="en" prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product#">
#  <!--<![endif]-->
#  <head>
#   <!--[if IE]><![endif]-->
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="//stats.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://ws.sharethis.com" rel="preconnect"/>
# ...

# %%
all_rows = soup_doc.find_all('tbody')[0].find_all('tr')
vac_table = []
for row in all_rows:
    vac_seat = {}
    vac_seat['Court'] = row.find_all(attrs={"data-th":"Court:"})[0].string
    vac_seat['Incumbent'] = row.find_all(attrs={"data-th":"Incumbent:"})[0].string
    vac_seat['Vacancy_Reason'] = row.find_all(attrs={"data-th":"Vacancy Reason:"})[0].string
    vac_seat['Vacancy_Date'] = row.find_all(attrs={"data-th":"Vacancy Date:"})[0].string
    vac_seat['Nominee'] = row.find_all(attrs={"data-th":"Nominee:"})[0].string
    vac_seat['Nomination_Date'] = row.find_all(attrs={"data-th":"Nomination Date:"})[0].string
    vac_table.append(vac_seat)
vac_table
# Out:
# [{'Court': '01 - MA',
#   'Incumbent': 'Woodlock,Douglas P.',
#   'Vacancy_Reason': 'Senior',
#   'Vacancy_Date': '06/01/2015',
#   'Nominee': None,
#   'Nomination_Date': None},
#  {'Court': '01 - MA',
#   'Incumbent': "O'Toole Jr.,George A.",
#   'Vacancy_Reason': 'Senior',
#   'Vacancy_Date': '01/01/2018',
#   'Nominee': None,
#   'Nomination_Date': None},
#  {'Court': '01 - PR',
#   'Incumbent': 'Garcia-Gregory,Jay A.',
#   'Vacancy_Reason': 'Senior',
#   'Vacancy_Date': '09/30/2018',
#   'Nominee': None,
#   'Nomination_Date': None},
#  {'Court': '01 - RI',
#   'Incumbent': 'Lisi,Mary M.',
#   'Vacancy_Reason': 'Senior',
#   'Vacancy_Date': '10/01/2015',
#   'Nominee': 'McElroy,Mary Susan',
#   'Nomination_Date': '05/21/2019'},
#  {'Court': '02 - CCA',
#   'Incumbent': 'Droney,Christopher F.',
#   'Vacancy_Reason': 'Senior',
#   'Vacancy_Date': '06/30/2019',
#   'Nominee': None,
#   'Nomination_Date': None},
#  {'Court': '02 - CCA',
#   'Incumbent': 'Jacobs,Dennis',
# ...

# %%
df = pd.DataFrame(vac_table)
df
# Out:
#          Court                   Incumbent Nomination_Date  \
# 0      01 - MA         Woodlock,Douglas P.            None
# 1      01 - MA       O'Toole Jr.,George A.            None
# 2      01 - PR       Garcia-Gregory,Jay A.            None
# 3      01 - RI                Lisi,Mary M.      05/21/2019
# 4     02 - CCA       Droney,Christopher F.            None
# 5     02 - CCA               Jacobs,Dennis            None
# 6      02 - CT           Thompson,Alvin W.            None
# 7    02 - NY-E            Bianco,Joseph F.            None
# 8    02 - NY-E        Feuerstein,Sandra J.      05/21/2019
# 9    02 - NY-E                Gleeson,John      05/21/2019
# 10   02 - NY-E           Vitaliano,Eric N.      05/21/2019
# 11   02 - NY-E           Amon,Carol Bagley      05/21/2019
# 12   02 - NY-N              Sharpe,Gary L.      01/23/2019
# 13   02 - NY-S        Forrest,Katherine B.            None
# 14   02 - NY-S       Pauley III,William H.            None
# ...

# %%
df.dtypes
# Out:
# Court              object
# Incumbent          object
# Nomination_Date    object
# Nominee            object
# Vacancy_Date       object
# Vacancy_Reason     object
# dtype: object
